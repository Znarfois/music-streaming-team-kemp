# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %%
#don't forget to revise the read path
df = pd.read_csv('C:/Users/knocom/Eskwelabs Jupyter Notebooks/Sprint 3/get_spotify_data-master/data/merged_charts_tracks_data.csv')

# %%
df.head()
# Out:
#          date  position                track_id   track_name  \
# 0  09/01/2019         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana
# 1  09/01/2019         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita
# 2  09/01/2019         3  1dGr1c8CrMLDpV6mPbImSI        Lover
# 3  09/01/2019         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako
# 4  09/01/2019         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin
#
#              artist  streams               artist_id       artist_name  \
# 0       Skusta Clee   267548  117XFtbZPnCI1EYKjYZWJc       Skusta Clee
# 1      Shawn Mendes   259828  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes
# 2      Taylor Swift   240408  06HL4z0CvFAxyc27GXpf02      Taylor Swift
# 3  Moira Dela Torre   236726  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre
# 4           Ben&Ben   190049  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben
#
#                  album_id  duration  ... energy  key  loudness  mode  \
# 0  4AaygWd1ZnCzZ4ak9EM23s    304664  ...  0.433    8    -8.518     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73200 entries, 0 to 73199
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              73200 non-null  object
#  1   position          73200 non-null  int64
#  2   track_id          73200 non-null  object
#  3   track_name        73200 non-null  object
#  4   artist            73200 non-null  object
#  5   streams           73200 non-null  int64
#  6   artist_id         73200 non-null  object
#  7   artist_name       73200 non-null  object
#  8   album_id          73200 non-null  object
#  9   duration          73200 non-null  int64
#  10  release_date      73200 non-null  object
#  11  popularity        73200 non-null  int64
#  12  danceability      73200 non-null  float64
#  13  energy            73200 non-null  float64
#  14  key               73200 non-null  int64
#  15  loudness          73200 non-null  float64
# ...

# %%
#convert column date to datetime type
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date  position                track_id   track_name            artist  \
# 0 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana       Skusta Clee
# 1 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita      Shawn Mendes
# 2 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI        Lover      Taylor Swift
# 3 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako  Moira Dela Torre
# 4 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin           Ben&Ben
#
#    streams               artist_id       artist_name                album_id  \
# 0   267548  117XFtbZPnCI1EYKjYZWJc       Skusta Clee  4AaygWd1ZnCzZ4ak9EM23s
# 1   259828  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes  0xzScN8P3hQAz3BT3YYX5w
# 2   240408  06HL4z0CvFAxyc27GXpf02      Taylor Swift  1NAmidJlEaVgA3MpcPFYGq
# 3   236726  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre  397zfeJ75BlnjfUEkgtwlG
# 4   190049  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben  7xCcuTA3abKwxj8HwgxP7R
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73200 entries, 0 to 73199
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              73200 non-null  datetime64[ns]
#  1   position          73200 non-null  int64
#  2   track_id          73200 non-null  object
#  3   track_name        73200 non-null  object
#  4   artist            73200 non-null  object
#  5   streams           73200 non-null  int64
#  6   artist_id         73200 non-null  object
#  7   artist_name       73200 non-null  object
#  8   album_id          73200 non-null  object
#  9   duration          73200 non-null  int64
#  10  release_date      73200 non-null  object
#  11  popularity        73200 non-null  int64
#  12  danceability      73200 non-null  float64
#  13  energy            73200 non-null  float64
#  14  key               73200 non-null  int64
#  15  loudness          73200 non-null  float64
# ...

# %%
df.describe()
# Out:
#          position        streams       duration    popularity  danceability  \
# count  73200.0000   73200.000000   73200.000000  73200.000000  73200.000000
# mean     100.5000   55187.094180  231657.148634     70.265929      0.624894
# std       57.7347   44208.310362   53746.551668     14.924452      0.140069
# min        1.0000   18324.000000   41866.000000      0.000000      0.184000
# 25%       50.7500   28465.500000  195186.000000     64.000000      0.523000
# 50%      100.5000   36579.000000  217946.000000     71.000000      0.638000
# 75%      150.2500   63725.500000  261426.000000     80.000000      0.721000
# max      200.0000  514546.000000  536217.000000    100.000000      0.940000
#
#             energy          key      loudness          mode   speechiness  \
# count  73200.00000  73200.00000  73200.000000  73200.000000  73200.000000
# mean       0.52873      5.54000     -7.421862      0.779372      0.071105
# ...

# %%
df = df.set_index('date')

# %%
df
# Out:
#             position                track_id             track_name  \
# date
# 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL               Zebbiana
# 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2               Señorita
# 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI                  Lover
# 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz            Ikaw At Ako
# 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd              Pagtingin
# ...              ...                     ...                    ...
# 2020-08-31       196  0tgVpDi06FyKpA1z0VMD4v                Perfect
# 2020-08-31       197  5zMR44ZH4KVZj4FlhTj3SE               Magbalik
# 2020-08-31       198  59qrUpoplZxbIZxk6X0Bm3       Take You Dancing
# 2020-08-31       199  2JoZzpdeP2G6Csfdq5aLXP  How Deep Is Your Love
# 2020-08-31       200  6BxJLJw228OY5BFerPGl7z                  Dahan
#
#                       artist  streams               artist_id  \
# date
# 2019-09-01       Skusta Clee   267548  117XFtbZPnCI1EYKjYZWJc
# ...

# %%
#create pivot table to aggregate the count of Top 200 appearances per track
df_mainstayraw = df.pivot_table(values='position', index=['track_id','artist','track_name'], aggfunc='count')

#df.pivot_table(values='D', index=['A','B'],columns='C', aggfunc='count')

# %%
#rename column 'position' to 'count of top 200 appearances'
df_mainstayraw2 = df_mainstayraw.rename(columns={'position':'count of top 200 appearances'}).sort_values(by='count of top 200 appearances',ascending=False)

# %%
#show songs that were part of the Top 200 everyday for all 366 days in the dataset.
df_mainstayraw2[(df_mainstayraw2['count of top 200 appearances']==366)]
# Out:
#                                                                                                count of top 200 appearances
# track_id               artist              track_name
# 00mBzIWv5gHOYxwuEJXjOG December Avenue     Sa Ngalan Ng Pag-Ibig                                                        366
# 6v3KW9xbzN5yKLt9YKDYA2 Shawn Mendes        Señorita                                                                     366
# 0HZ3OUVrGHxttD2EuHqRm3 Hale                The Day You Said Goodnight                                                   366
# 34ob61cxp34Sf7KHK6RnSU PDL                 Sa Susunod Na Lang                                                           366
# 6NFKf8vBApSvtzkapYmnVR Up Dharma Down      Tadhana                                                                      366
# 6IdEQ3HUseBeRUYFSzSMdL Skusta Clee         Zebbiana                                                                     366
# ...

# %%
#number of songs which were in the Top 200 everyday
df_mainstayraw2[(df_mainstayraw2['count of top 200 appearances']==366)].count()
# Out:
# count of top 200 appearances    38
# dtype: int64

# %%
#reset index 
df_mainstayraw2.reset_index(inplace=True)

# %%
df_mainstayraw2
# Out:
#                     track_id            artist                  track_name  \
# 0     00mBzIWv5gHOYxwuEJXjOG   December Avenue       Sa Ngalan Ng Pag-Ibig
# 1     6v3KW9xbzN5yKLt9YKDYA2      Shawn Mendes                    Señorita
# 2     0HZ3OUVrGHxttD2EuHqRm3              Hale  The Day You Said Goodnight
# 3     34ob61cxp34Sf7KHK6RnSU               PDL          Sa Susunod Na Lang
# 4     6NFKf8vBApSvtzkapYmnVR    Up Dharma Down                     Tadhana
# ...                      ...               ...                         ...
# 1027  3vsNteZn6E5qBSSBO78W7b       James Blunt            You're Beautiful
# 1028  0pobQmvHou3syiOi6DRqiC            Hotdog                      Manila
# 1029  6YQlCOZnlFmqeciAh58fDE          Coldplay                     Orphans
# 1030  6ZDueLAHQXEGfgR3piQ0i1  Yeng Constantino              Pasko Sa Pinas
# 1031  3fEoJxnPpfIHwFHKiFtqbA        Little Mix               Break Up Song
#
#       count of top 200 appearances
# ...

# %%
#np.set_printoptions(threshold=np.inf) 
#remove automatic truncation when showing np arrays, don't use this if handling extremely large datasets

# %%
df_mainstayraw2[(df_mainstayraw2['count of top 200 appearances']==366)]['track_id'].values
# Out:
# array(['00mBzIWv5gHOYxwuEJXjOG', '6v3KW9xbzN5yKLt9YKDYA2',
#        '0HZ3OUVrGHxttD2EuHqRm3', '34ob61cxp34Sf7KHK6RnSU',
#        '6NFKf8vBApSvtzkapYmnVR', '6IdEQ3HUseBeRUYFSzSMdL',
#        '3OpGUlDmRUXh0NkIYWoIlD', '3WUEs51GpcvlgU7lehLgLh',
#        '6C2nrsOlb3jOUGcJAmPrTA', '3e9HZxeyfWwjeyPAMmWSSQ',
#        '3ueq4reab02CypseErxvwS', '3vGkyQlCw8LklNip0ZUELC',
#        '5uCax9HTNlzGybIStD3vDh', '0Vmk6Ebk4QBq7r0VAz2a6s',
#        '5l9g7py8RCblcvbZgGQgSd', '5f9808hpiCpuNyqqdXmpF2',
#        '5UhpceEr5XmbVwyoIUIRnh', '4JSDhJVmo2UqdF7nxbyenn',
#        '4OBZT9EnhYIV17t4pGw7ig', '4a6q8CR2hzLk2plDkSxkfD',
#  '3vGkyQlCw8LklNip0ZUELC',
#  '5uCax9HTNlzGybIStD3vDh',
#  '0Vmk6Ebk4QBq7r0VAz2a6s',
#  '5l9g7py8RCblcvbZgGQgSd',
#  '5f9808hpiCpuNyqqdXmpF2',
#  '5UhpceEr5XmbVwyoIUIRnh',
#  '4JSDhJVmo2UqdF7nxbyenn',
#  '4OBZT9EnhYIV17t4pGw7ig',
#  '4a6q8CR2hzLk2plDkSxkfD',
#  '5KawlOMHjWeUjQtnuRs22c',
#  '1X4l4i472kW5ofFP8Xo0x0',
#  '58grXgbCj7t5ulr0TGLIr9',
#  '4u8RkgV6P4TLi89SmlUtv8',
#  '0gDRtumoR9ZrvAlnniToMz',
#  '135ggzbjOogZ75IQ0LQi8r',
#  '0hVXuCcriWRGvwMV1r5Yn9',
#  '0Eqg0CQ7bK3RQIMPw1A7pl',
#  '6wdCelHrPh7UfliNjwRTUv',
#  '2BgD4nRyx9EZ5o8YEnjRSV',
#  '24ngpWhBOxKJtIPnzSNX8c',
#  '2BgEsaKNfHUdlh97KmvFyo',
#  '70eFcWOvlMObDhURTqT4Fv',
#  '2P91MQbaiQOfbiz9VqhqKQ',
# ...

# %%
#create is_mainstay column tagging the 38 songs with a True value if they are part of the mainstay_list
df['is_mainstay'] = df['track_id'].apply(lambda x: 1 if x in mainstay_list else 0)

# %%
#59,292 rows are not mainstay while 13,908 rows are considered mainstay
df['is_mainstay'].value_counts()
# Out:
# 0    59292
# 1    13908
# Name: is_mainstay, dtype: int64

# %%
df.head(20)
# Out:
#             position                track_id  \
# date
# 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL
# 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2
# 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI
# 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz
# 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd
# 2019-09-01         6  34ob61cxp34Sf7KHK6RnSU
# 2019-09-01         7  70eFcWOvlMObDhURTqT4Fv
# 2019-09-01         8  2BgD4nRyx9EZ5o8YEnjRSV
# 2019-09-01         9  1X4l4i472kW5ofFP8Xo0x0
# 2019-09-01        10  18uwL0vNUanqZH0ro2QcOP
# 2019-09-01        11  0hVXuCcriWRGvwMV1r5Yn9
# 2019-09-01        12  6b2RcmUt1g9N9mQ3CbjX2Y
# 2019-09-01        13  1BxfuPKGuaTgP7aM0Bbdwr
# 2019-09-01        14  1yDiru08Q6omDOGkZMPnei
# 2019-09-01        15  6vBdBCoOhKHiYDDOcorfNo
# 2019-09-01        16  2RgD3eO4IIGF16rR8Ch8OV
# 2019-09-01        17  6RRNNciQGZEXnqk8SQ9yv5
# 2019-09-01        18  24ngpWhBOxKJtIPnzSNX8c
# 2019-09-01        19  4a6q8CR2hzLk2plDkSxkfD
# 2019-09-01        20  1pNAf6W7POwjOD8x8mWf8G
#
# ...

# %%
#The next set of cells are just me exploring and getting used to the resampling functions taught by JC. 
#You can skip all the way to the next uncommented cell.

# %%
#mon_df = df['streams'].resample('M').sum() #M for month
#mon_df
# Out:
# date
# 2019-09-30    340254556
# 2019-10-31    361953677
# 2019-11-30    356435728
# 2019-12-31    376737312
# 2020-01-31    386949218
# 2020-02-29    373569531
# 2020-03-31    343451485
# 2020-04-30    273068617
# 2020-05-31    282020357
# 2020-06-30    299742531
# 2020-07-31    334615639
# 2020-08-31    310896643
# Freq: M, Name: streams, dtype: int64

# %%
#df[df['track_id']=='1dGr1c8CrMLDpV6mPbImSI']['streams'].resample('M').sum()
# Out:
# date
# 2019-09-30    5280302
# 2019-10-31    3388501
# 2019-11-30    1912500
# 2019-12-31    1492922
# 2020-01-31    1283073
# 2020-02-29    1325768
# 2020-03-31    1095894
# 2020-04-30     840337
# 2020-05-31     908480
# 2020-06-30     897098
# 2020-07-31     956367
# 2020-08-31     539947
# Freq: M, Name: streams, dtype: int64

# %%
#Define and find Viral songs

# %%
#mon_df[(mon_df[]
# Out:
# date
# 2019-09-30           NaN
# 2019-10-31    21699121.0
# 2019-11-30    -5517949.0
# 2019-12-31    20301584.0
# 2020-01-31    10211906.0
# 2020-02-29   -13379687.0
# 2020-03-31   -30118046.0
# 2020-04-30   -70382868.0
# 2020-05-31     8951740.0
# 2020-06-30    17722174.0
# 2020-07-31    34873108.0
# 2020-08-31   -23718996.0
# Freq: M, Name: streams, dtype: float64

# %%
#track change in position vs previous day
#df[(df['track_name']=='Maybe The Night')]['position'].resample('D').mean().diff()
# Out:
# date
# 2019-09-01    NaN
# 2019-09-02    0.0
# 2019-09-03    0.0
# 2019-09-04    0.0
# 2019-09-05   -1.0
#              ...
# 2020-08-27    0.0
# 2020-08-28    1.0
# 2020-08-29    1.0
# 2020-08-30    1.0
# 2020-08-31   -3.0
# Freq: D, Name: position, Length: 366, dtype: float64

# %%
#track change in streams vs previous month
#df[(df['track_name']=='Maybe The Night')]['streams'].resample('M').sum().diff()
# Out:
# date
# 2019-09-30         NaN
# 2019-10-31   -824815.0
# 2019-11-30   -324240.0
# 2019-12-31    353726.0
# 2020-01-31    101098.0
# 2020-02-29    357909.0
# 2020-03-31   -356643.0
# 2020-04-30   -880643.0
# 2020-05-31    -27465.0
# 2020-06-30     31705.0
# 2020-07-31    191724.0
# 2020-08-31     -7517.0
# Freq: M, Name: streams, dtype: float64

# %%
#OPTIONAL TO RUN: expand pandas truncate rows condition to 999 from 15 
pd.set_option('display.max_rows',999)

# %%
pd.options.display.max_rows
# Out:
# 999

# %%
#df[(df['track_id']=='0gDRtumoR9ZrvAlnniToMz')]['streams'].resample('D').sum().diff()
# Out:
# date
# 2019-09-01        NaN
# 2019-09-02      625.0
# 2019-09-03     5149.0
# 2019-09-04      208.0
# 2019-09-05     -127.0
# 2019-09-06    -7484.0
# 2019-09-07     2844.0
# 2019-09-08      913.0
# 2019-09-09    -5569.0
# 2019-09-10     2905.0
# 2019-09-11     2892.0
# 2019-09-12     1982.0
# 2019-09-13    -8325.0
# 2019-09-14     1902.0
# 2019-09-15    -1582.0
# 2019-09-16    -5400.0
# 2019-09-17     2847.0
# 2019-09-18   -12612.0
# 2019-09-19     -156.0
# 2019-09-20    -8422.0
# 2019-09-21    -7321.0
# 2019-09-22     -937.0
# 2019-09-23    -2848.0
# 2019-09-24    -3025.0
# 2019-09-25     -830.0
# 2019-09-26      193.0
# 2019-09-27     -332.0
# 2019-09-28    -2202.0
# 2019-09-29    -6440.0
# 2019-09-30     7755.0
# 2019-10-01    -6147.0
# 2019-10-02     -331.0
# 2019-10-03     2739.0
# 2019-10-04     6330.0
# 2019-10-05    -1891.0
# 2019-10-06     -773.0
# 2019-10-07     -661.0
# 2019-10-08    -1140.0
# 2019-10-09     5855.0
# 2019-10-10     2925.0
# 2019-10-11    -1695.0
# ...

# %%
#Song Identifier Tool: Given track_id, provide track_name
df[df['track_id']=='4Oun2ylbjFKMPTiaSbbCih'].head(1)
# Out:
#             position                track_id                       track_name  \
# date
# 2020-08-08        94  4Oun2ylbjFKMPTiaSbbCih  WAP (feat. Megan Thee Stallion)
#
#              artist  streams               artist_id artist_name  \
# date
# 2020-08-08  Cardi B    34418  4kYSro6naA4h99UJvo89HB     Cardi B
#
#                           album_id  duration release_date  ...  key  loudness  \
# date                                                       ...
# 2020-08-08  2ogiazbrNEx0kQHGl5ZBTQ    187541   08/07/2020  ...    1    -7.509
#
#             mode  speechiness  acousticness  instrumentalness  liveness  \
# date
# 2020-08-08     1        0.375        0.0194               0.0    0.0824
#
#             valence    tempo  is_mainstay
# date
# 2020-08-08    0.357  133.073            0
#
# [1 rows x 23 columns]

# %%
#WAP (feat. Megan Thee Stallion) daily position values
#df[(df['track_id']=='4Oun2ylbjFKMPTiaSbbCih')]['position'].resample('D').sum()
# Out:
# date
# 2020-08-08    94
# 2020-08-09    73
# 2020-08-10    69
# 2020-08-11    59
# 2020-08-12    43
# 2020-08-13    24
# 2020-08-14    20
# 2020-08-15    18
# 2020-08-16    19
# 2020-08-17    16
# 2020-08-18    16
# 2020-08-19    15
# 2020-08-20    10
# 2020-08-21    11
# 2020-08-22     9
# 2020-08-23     9
# 2020-08-24     5
# 2020-08-25     5
# 2020-08-26     4
# 2020-08-27     4
# 2020-08-28     6
# 2020-08-29     6
# 2020-08-30     6
# 2020-08-31     6
# Freq: D, Name: position, dtype: int64

# %%
#WAP (feat. Megan Thee Stallion) daily position values incremental difference
#df[(df['track_id']=='4Oun2ylbjFKMPTiaSbbCih')]['position'].resample('D').sum().diff()
# Out:
# date
# 2020-08-08     NaN
# 2020-08-09   -21.0
# 2020-08-10    -4.0
# 2020-08-11   -10.0
# 2020-08-12   -16.0
# 2020-08-13   -19.0
# 2020-08-14    -4.0
# 2020-08-15    -2.0
# 2020-08-16     1.0
# 2020-08-17    -3.0
# 2020-08-18     0.0
# 2020-08-19    -1.0
# 2020-08-20    -5.0
# 2020-08-21     1.0
# 2020-08-22    -2.0
# 2020-08-23     0.0
# 2020-08-24    -4.0
# 2020-08-25     0.0
# 2020-08-26    -1.0
# 2020-08-27     0.0
# 2020-08-28     2.0
# 2020-08-29     0.0
# 2020-08-30     0.0
# 2020-08-31     0.0
# Freq: D, Name: position, dtype: float64

# %%
#WAP (feat. Megan Thee Stallion) Rolling 7 Days Average Position Values
#df[(df['track_id']=='4Oun2ylbjFKMPTiaSbbCih')]['position'].rolling(7).mean()
# Out:
# date
# 2020-08-08          NaN
# 2020-08-09          NaN
# 2020-08-10          NaN
# 2020-08-11          NaN
# 2020-08-12          NaN
# 2020-08-13          NaN
# 2020-08-14    54.571429
# 2020-08-15    43.714286
# 2020-08-16    36.000000
# 2020-08-17    28.428571
# 2020-08-18    22.285714
# 2020-08-19    18.285714
# 2020-08-20    16.285714
# 2020-08-21    15.000000
# 2020-08-22    13.714286
# 2020-08-23    12.285714
# 2020-08-24    10.714286
# 2020-08-25     9.142857
# 2020-08-26     7.571429
# 2020-08-27     6.714286
# 2020-08-28     6.000000
# 2020-08-29     5.571429
# 2020-08-30     5.142857
# 2020-08-31     5.285714
# Name: position, dtype: float64

# %%
#WAP (feat. Megan Thee Stallion) Rolling 7 Days Standard Deviation Position
#df[(df['track_id']=='4Oun2ylbjFKMPTiaSbbCih')]['position'].rolling(7).std()
# Out:
# date
# 2020-08-08          NaN
# 2020-08-09          NaN
# 2020-08-10          NaN
# 2020-08-11          NaN
# 2020-08-12          NaN
# 2020-08-13          NaN
# 2020-08-14    27.036131
# 2020-08-15    23.605891
# 2020-08-16    21.134490
# 2020-08-17    16.277358
# 2020-08-18     9.534399
# 2020-08-19     3.093773
# 2020-08-20     3.302236
# 2020-08-21     3.366502
# 2020-08-22     3.728909
# 2020-08-23     3.251373
# 2020-08-24     3.773340
# 2020-08-25     3.484660
# 2020-08-26     2.819997
# 2020-08-27     2.870208
# 2020-08-28     2.160247
# 2020-08-29     1.718249
# 2020-08-30     0.899735
# 2020-08-31     0.951190
# Name: position, dtype: float64

# %%
#Song Identifier Tool: Given track_id, provide track_name
df[df['track_id']=='1yDiru08Q6omDOGkZMPnei'].head(1)
# Out:
#             position                track_id       track_name   artist  \
# date
# 2019-09-01        14  1yDiru08Q6omDOGkZMPnei  Maybe The Night  Ben&Ben
#
#             streams               artist_id artist_name  \
# date
# 2019-09-01   132927  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben
#
#                           album_id  duration release_date  ...  key  loudness  \
# date                                                       ...
# 2019-09-01  6LhZ3QMHGJeTes9cCTxK8e    217197   10/27/2017  ...    2    -9.095
#
#             mode  speechiness  acousticness  instrumentalness  liveness  \
# date
# 2019-09-01     1       0.0367         0.113          0.000049     0.114
#
#             valence  tempo  is_mainstay
# date
# 2019-09-01    0.498  74.05            1
#
# [1 rows x 23 columns]

# %%
#Maybe the Night - Ben & Ben daily position values
#df[(df['track_id']=='1yDiru08Q6omDOGkZMPnei')]['position'].resample('D').sum()
# Out:
# date
# 2019-09-01    14
# 2019-09-02    14
# 2019-09-03    14
# 2019-09-04    14
# 2019-09-05    13
# 2019-09-06    15
# 2019-09-07    16
# 2019-09-08    15
# 2019-09-09    14
# 2019-09-10    13
# 2019-09-11    13
# 2019-09-12    13
# 2019-09-13    13
# 2019-09-14    13
# 2019-09-15    13
# 2019-09-16    12
# 2019-09-17    12
# 2019-09-18    14
# 2019-09-19    17
# 2019-09-20    18
# 2019-09-21    21
# 2019-09-22    22
# 2019-09-23    22
# 2019-09-24    22
# 2019-09-25    21
# 2019-09-26    22
# 2019-09-27    23
# 2019-09-28    23
# 2019-09-29    21
# 2019-09-30    21
# 2019-10-01    23
# 2019-10-02    23
# 2019-10-03    24
# 2019-10-04    28
# 2019-10-05    30
# 2019-10-06    30
# 2019-10-07    30
# 2019-10-08    29
# 2019-10-09    30
# 2019-10-10    30
# 2019-10-11    34
# 2019-10-12    32
# 2019-10-13    33
# 2019-10-14    34
# 2019-10-15    33
# 2019-10-16    35
# 2019-10-17    35
# 2019-10-18    37
# 2019-10-19    37
# 2019-10-20    35
# 2019-10-21    32
# 2019-10-22    34
# ...

# %%
#Maybe the Night - Ben & Ben Rolling 7 Days Average Position Values
#df[(df['track_id']=='1yDiru08Q6omDOGkZMPnei')]['position'].rolling(7).mean()
# Out:
# date
# 2019-09-01          NaN
# 2019-09-02          NaN
# 2019-09-03          NaN
# 2019-09-04          NaN
# 2019-09-05          NaN
# 2019-09-06          NaN
# 2019-09-07    14.285714
# 2019-09-08    14.428571
# 2019-09-09    14.428571
# 2019-09-10    14.285714
# 2019-09-11    14.142857
# 2019-09-12    14.142857
# 2019-09-13    13.857143
# 2019-09-14    13.428571
# 2019-09-15    13.142857
# 2019-09-16    12.857143
# 2019-09-17    12.714286
# 2019-09-18    12.857143
# 2019-09-19    13.428571
# 2019-09-20    14.142857
# 2019-09-21    15.285714
# 2019-09-22    16.571429
# 2019-09-23    18.000000
# 2019-09-24    19.428571
# 2019-09-25    20.428571
# 2019-09-26    21.142857
# 2019-09-27    21.857143
# 2019-09-28    22.142857
# 2019-09-29    22.000000
# 2019-09-30    21.857143
# 2019-10-01    22.000000
# 2019-10-02    22.285714
# 2019-10-03    22.571429
# 2019-10-04    23.285714
# 2019-10-05    24.285714
# 2019-10-06    25.571429
# 2019-10-07    26.857143
# 2019-10-08    27.714286
# ...

# %%
#Maybe the Night - Ben & Ben Rolling 7 Days Standard Deviation Position
#df[(df['track_id']=='1yDiru08Q6omDOGkZMPnei')]['position'].rolling(7).std()
# Out:
# date
# 2019-09-01         NaN
# 2019-09-02         NaN
# 2019-09-03         NaN
# 2019-09-04         NaN
# 2019-09-05         NaN
# 2019-09-06         NaN
# 2019-09-07    0.951190
# 2019-09-08    0.975900
# 2019-09-09    0.975900
# 2019-09-10    1.112697
# 2019-09-11    1.214986
# 2019-09-12    1.214986
# 2019-09-13    1.214986
# 2019-09-14    0.786796
# 2019-09-15    0.377964
# 2019-09-16    0.377964
# 2019-09-17    0.487950
# 2019-09-18    0.690066
# 2019-09-19    1.718249
# 2019-09-20    2.410295
# 2019-09-21    3.450328
# 2019-09-22    4.076647
# 2020-08-04    0.534522
# ...

# %%
#BLACKPINK - How You Like That daily position values
#df[(df['track_id']=='3vAn0qZzdyuHamcrpkfiX3')]['position'].resample('D').sum()
# Out:
# date
# 2020-06-27     1
# 2020-06-28     1
# 2020-06-29     1
# 2020-06-30     1
# 2020-07-01     1
# 2020-07-02     1
# 2020-07-03     1
# 2020-07-04     1
# 2020-07-05     1
# 2020-07-06     1
# 2020-07-07     1
# 2020-07-08     1
# 2020-07-09     1
# 2020-07-10     1
# 2020-07-11     1
# 2020-07-12     1
# 2020-07-13     1
# 2020-07-14     1
# 2020-07-15     1
# 2020-07-16     1
# 2020-07-17     1
# 2020-07-18     1
# 2020-07-19     1
# 2020-07-20     1
# 2020-07-21     1
# 2020-07-22     1
# 2020-07-23     1
# 2020-07-24    12
# 2020-07-25     8
# 2020-07-26     5
# 2020-07-27     4
# 2020-07-28     4
# 2020-07-29     3
# 2020-07-30     3
# 2020-07-31     2
# 2020-08-01     2
# 2020-08-02     3
# 2020-08-03     2
# 2020-08-04     3
# 2020-08-05     3
# 2020-08-06     2
# 2020-08-07     1
# 2020-08-08     2
# 2020-08-09     2
# 2020-08-10     1
# 2020-08-11     4
# 2020-08-12     4
# 2020-08-13     4
# 2020-08-14     4
# 2020-08-15     5
# 2020-08-16     5
# 2020-08-17     5
# ...

# %%
#Miley Cyrus - When I Look at You 7 Days Standard Deviation Position
df[(df['track_id']=='6ZfXA2xakAvphXOSOJ3u1W')]['position'].rolling(7).std()
# Out:
# date
# 2020-08-14          NaN
# 2020-08-15          NaN
# 2020-08-16          NaN
# 2020-08-17          NaN
# 2020-08-18          NaN
# 2020-08-19          NaN
# 2020-08-20    24.748256
# 2020-08-21    11.586116
# 2020-08-22    16.826849
# 2020-08-23    20.173061
# 2020-08-24    20.477630
# 2020-08-25    19.505799
# 2020-08-26    16.460631
# 2020-08-27    11.296860
# 2020-08-28     3.436499
# 2020-08-29     2.225395
# 2020-08-30     1.799471
# 2020-08-31     1.154701
# Name: position, dtype: float64

# %%
#Miley Cyrus - When I Look at You : find maximum rolling 7 standard deviation jump 
#This value will be used to measure how quickly the track jumped up the charts. Higher Rolling 7 STDEV= MORE VIRAL!
df[(df['track_id']=='6ZfXA2xakAvphXOSOJ3u1W')]['position'].rolling(7).std().max()
# Out:
# 24.748256311833174

# %%
df.groupby('track_id')['position'].min()<=100
# Out:
# track_id
# 00mBzIWv5gHOYxwuEJXjOG     True
# 011GTFfE8rqTRMhz5g8IAW     True
# 017PF4Q3l4DBUiWoXk4OWT     True
# 0247StOpd3AkeBQzANX4Zf    False
# 029B34AzPVXzOQCyaJpkdH     True
#                           ...
# 7xty20N3DMTVOVtDIS2Jov    False
# 7y7w4tl4MaRC2UMEj1mPtr    False
# 7yBbV2k2S2uhaQc24NF2xt     True
# 7ytR5pFWmSjzHJIeQkgog4     True
# 7zFBtYAVURF3bUVqEQ6UUu    False
# Name: position, Length: 1032, dtype: bool

# %%
#create pivot table to obtain minimum position (best) per track
df_viralraw = df.pivot_table(values='position', index=['track_id','artist','track_name'], aggfunc='min')

# %%
df_viralraw
# Out:
#                                                                                            position
# track_id               artist          track_name
# 00mBzIWv5gHOYxwuEJXjOG December Avenue Sa Ngalan Ng Pag-Ibig                                     26
# 011GTFfE8rqTRMhz5g8IAW Al James        Repeat                                                    43
# 017PF4Q3l4DBUiWoXk4OWT Dua Lipa        Break My Heart                                            15
# 0247StOpd3AkeBQzANX4Zf Band Aid        Do They Know It's Christmas? - 1984 Version              125
# 029B34AzPVXzOQCyaJpkdH Lauv            Changes                                                   41
# ...                                                                                             ...
# 7xty20N3DMTVOVtDIS2Jov Darren Espanto  Dying Inside To Hold You - From " All Of You" O...       173
# 7y7w4tl4MaRC2UMEj1mPtr Juice WRLD      Come & Go (with Marshmello)                              104
# ...

# %%
#rename position column to best top 200 position
df_viralraw2 = df_viralraw.rename(columns={'position':'best top 200 position'}).sort_values(by='best top 200 position',ascending=True)

# %%
df_viralraw2
# Out:
#                                                                                 best top 200 position
# track_id               artist         track_name
# 47UUjZbqZjcrzELnFBB1Ht Emman          Teka Lang                                                     1
# 0Jlcvv8IykzHaSmj49uNW8 Taylor Swift   the 1                                                         1
# 4HBZA5flZLE435QTztThqH Ariana Grande  Stuck with U (with Justin Bieber)                             1
# 6R6ZoHTypt5lt68MWbzZXv Lady Gaga      Sour Candy (with BLACKPINK)                                   1
# 65sEZZaxTjLMD8vNgPoMz5 Magnus Haven   Imahe                                                         1
# ...                                                                                               ...
# 6sl4KzZ9PRb8xTzjYIrHAP Leanne & Naara Someday                                                     200
# 1Slwb6dOYkBlWal1PGtnNg Ed Sheeran     Thinking out Loud                                           200
# ...

# %%
#count # of tracks which were able to reach at least the Top 100 at least once in the past year
df_viralraw2[(df_viralraw2['best top 200 position']<=100)].count()
# Out:
# best top 200 position    609
# dtype: int64

# %%
#reset index 
df_viralraw2.reset_index(inplace=True)

# %%
df_viralraw2
# Out:
#                     track_id          artist  \
# 0     47UUjZbqZjcrzELnFBB1Ht           Emman
# 1     0Jlcvv8IykzHaSmj49uNW8    Taylor Swift
# 2     4HBZA5flZLE435QTztThqH   Ariana Grande
# 3     6R6ZoHTypt5lt68MWbzZXv       Lady Gaga
# 4     65sEZZaxTjLMD8vNgPoMz5    Magnus Haven
# ...                      ...             ...
# 1027  6sl4KzZ9PRb8xTzjYIrHAP  Leanne & Naara
# 1028  1Slwb6dOYkBlWal1PGtnNg      Ed Sheeran
# 1029  5qrSlOut2rNAWv3ubArkNy      Dean Lewis
# 1030  0yYwS7CXKIPC4kWPvZQfsT           Bazzi
# 1031  4e4fqjx0Izh4svvTef1z7e      Bebe Rexha
#
#                                     track_name  best top 200 position
# 0                                    Teka Lang                      1
# 1                                        the 1                      1
# 2            Stuck with U (with Justin Bieber)                      1
# 3                  Sour Candy (with BLACKPINK)                      1
# ...

# %%
df_viralraw2[(df_viralraw2['best top 200 position']<=100)]['track_id'].values
# Out:
# array(['47UUjZbqZjcrzELnFBB1Ht', '0Jlcvv8IykzHaSmj49uNW8',
       '5RsKelNxucrDxgMbZ3vd3W', '3D110t9ctcoOoylXsc3iR8',
       '3S0OXQeoh0w6AY8WQVckRW', '47Bg6IrMed1GPbxRgwH2aC',
       '5BvZvsJbu9MqMKrTTseLrx', '7eOkHIcaoUhngxxypM5Ajr',
       '0YyM8aEdbjGfLWPn6fdcn7']

# %%
#create is_Top100 column tagging the 609 songs with a True value if they are part of the Top100_achievers list
df['is_Top100'] = df['track_id'].apply(lambda x: 1 if x in Top100_achievers else 0)

# %%
df.head()
# Out:
#             position                track_id   track_name            artist  \
# date
# 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana       Skusta Clee
# 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita      Shawn Mendes
# 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI        Lover      Taylor Swift
# 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako  Moira Dela Torre
# 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin           Ben&Ben
#
#             streams               artist_id       artist_name  \
# date
# 2019-09-01   267548  117XFtbZPnCI1EYKjYZWJc       Skusta Clee
# 2019-09-01   259828  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes
# 2019-09-01   240408  06HL4z0CvFAxyc27GXpf02      Taylor Swift
# 2019-09-01   236726  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre
# 2019-09-01   190049  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben
#
#                           album_id  duration release_date  ...  loudness  \
# ...

# %%
#create new df based on the tracks that were able to reach Top 100 at least once in the past year
df_Top100 = df[df['is_Top100']==1]
df_Top100
# Out:
#             position                track_id             track_name  \
# date
# 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL               Zebbiana
# 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2               Señorita
# 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI                  Lover
# 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz            Ikaw At Ako
# 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd              Pagtingin
# ...              ...                     ...                    ...
# 2020-08-31       192  4T7CM071eEoHudiDShZlCJ                   Tala
# 2020-08-31       193  1TaQciB8qqRZ9fxWGhS65X  Don't Know What To Do
# 2020-08-31       195  3xaugmCyXrVkrDTXbFkMW3              Sanctuary
# 2020-08-31       197  5zMR44ZH4KVZj4FlhTj3SE               Magbalik
# 2020-08-31       200  6BxJLJw228OY5BFerPGl7z                  Dahan
#
#                       artist  streams               artist_id  \
# date
# 2019-09-01       Skusta Clee   267548  117XFtbZPnCI1EYKjYZWJc
# ...

# %%
#df[(df['track_id']=='6ZfXA2xakAvphXOSOJ3u1W')]['position'].rolling(7).std().max()
# Out:
# 24.748256311833174

# %%
#use for loop to append each Top 100 song's maximum 7 day rolling standard deviation to the respective lists
Top100_track_id = []
Top100_track_name = []
Top100_maxrolling7stdev = []

for n in np.arange(0,len(df_Top100)):
        if df_Top100['track_id'][n] not in Top100_track_id:
            Top100_track_id.append(df_Top100['track_id'][n])
            Top100_track_name.append(df_Top100['track_name'][n])
            Top100_maxrolling7stdev.append(df_Top100[(df_Top100['track_id']==df_Top100['track_id'][n])]['position'].rolling(7).std().max())

# %%
#check if list lengths match
len(Top100_maxrolling7stdev)==len(Top100_track_id)==len(Top100_track_name)
# Out:
# True

# %%
len(Top100_track_name)
# Out:
# 609

# %%
Top100_track_id
# Out:
# ['6IdEQ3HUseBeRUYFSzSMdL',
#  '6v3KW9xbzN5yKLt9YKDYA2',
#  '1dGr1c8CrMLDpV6mPbImSI',
#  '0gDRtumoR9ZrvAlnniToMz',
#  '5l9g7py8RCblcvbZgGQgSd',
#  '34ob61cxp34Sf7KHK6RnSU',
#  '70eFcWOvlMObDhURTqT4Fv',
#  '2BgD4nRyx9EZ5o8YEnjRSV',
#  '1X4l4i472kW5ofFP8Xo0x0',
#  '18uwL0vNUanqZH0ro2QcOP',
#  '0hVXuCcriWRGvwMV1r5Yn9',
#  '6b2RcmUt1g9N9mQ3CbjX2Y',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '1yDiru08Q6omDOGkZMPnei',
#  '6vBdBCoOhKHiYDDOcorfNo',
#  '2RgD3eO4IIGF16rR8Ch8OV',
#  '6RRNNciQGZEXnqk8SQ9yv5',
#  '24ngpWhBOxKJtIPnzSNX8c',
#  '4a6q8CR2hzLk2plDkSxkfD',
#  '1pNAf6W7POwjOD8x8mWf8G',
#  '322tcqPhma7F6hfCeLisx0',
#  '3WUEs51GpcvlgU7lehLgLh',
#  '7hoP5NDUXEbmOawvEAsi8h',
#  '6BxJLJw228OY5BFerPGl7z',
#  '2mwd0LWLBgtQBEOLG96nbU',
#  '3KkXRkHbMCARz0aVfEt68P',
#  '3RauEVgRgj1IuWdJ9fDs70',
#  '3xaugmCyXrVkrDTXbFkMW3',
#  '6TqXcAFInzjp0bODyvrWEq',
#  '14BG5B1EJSCyNpZt096xXc',
#  '0Ryd8975WihbObpp5cPW1t',
#  '5NXdUJ3Z2jhlp2u1cj6f7m',
#  '2YpeDb67231RjR0MgVLzsG',
#  '3iZB3VUDerY5P96rhBKwKr',
# ...

# %%
#combine the three lists into a dataFrame
df_Top100withstdev = pd.DataFrame(
    {'track_id': Top100_track_id,
     'track_name': Top100_track_name,
     'max_rolling7_stdev': Top100_maxrolling7stdev
    })

# %%
df_Top100withstdev
# Out:
#                    track_id  \
# 0    6IdEQ3HUseBeRUYFSzSMdL
# 1    6v3KW9xbzN5yKLt9YKDYA2
# 2    1dGr1c8CrMLDpV6mPbImSI
# 3    0gDRtumoR9ZrvAlnniToMz
# 4    5l9g7py8RCblcvbZgGQgSd
# 5    34ob61cxp34Sf7KHK6RnSU
# 6    70eFcWOvlMObDhURTqT4Fv
# 7    2BgD4nRyx9EZ5o8YEnjRSV
# 8    1X4l4i472kW5ofFP8Xo0x0
# 9    18uwL0vNUanqZH0ro2QcOP
# 10   0hVXuCcriWRGvwMV1r5Yn9
# 11   6b2RcmUt1g9N9mQ3CbjX2Y
# 12   1BxfuPKGuaTgP7aM0Bbdwr
# 13   1yDiru08Q6omDOGkZMPnei
# 14   6vBdBCoOhKHiYDDOcorfNo
# 15   2RgD3eO4IIGF16rR8Ch8OV
# 16   6RRNNciQGZEXnqk8SQ9yv5
# 17   24ngpWhBOxKJtIPnzSNX8c
# 18   4a6q8CR2hzLk2plDkSxkfD
# 19   1pNAf6W7POwjOD8x8mWf8G
# 20   322tcqPhma7F6hfCeLisx0
# 21   3WUEs51GpcvlgU7lehLgLh
# 22   7hoP5NDUXEbmOawvEAsi8h
# 23   6BxJLJw228OY5BFerPGl7z
# 24   2mwd0LWLBgtQBEOLG96nbU
# 25   3KkXRkHbMCARz0aVfEt68P
# 26   3RauEVgRgj1IuWdJ9fDs70
# 27   3xaugmCyXrVkrDTXbFkMW3
# 28   6TqXcAFInzjp0bODyvrWEq
# 29   14BG5B1EJSCyNpZt096xXc
# 30   0Ryd8975WihbObpp5cPW1t
# 31   5NXdUJ3Z2jhlp2u1cj6f7m
# ...

# %%
df_Top100withstdev.describe()
# Out:
#        max_rolling7_stdev
# count          480.000000
# mean            28.770960
# std             15.008207
# min              0.377964
# 25%             17.551512
# 50%             26.664997
# 75%             37.810597
# max             78.930047

# %%
#get count of the most viral songs as seen in their large rolling 7 day standard deviation. 
#Top 25% percentile tracks have a max rolling 7 stdev of >37.810597. 
#Will use >=38 as the threshold value for max rolling 7 stdev to be considered viral.
df_Top100withstdev[df_Top100withstdev['max_rolling7_stdev']>=38].count()
# Out:
# track_id              120
# track_name            120
# max_rolling7_stdev    120
# dtype: int64

# %%
#classify songs as viral based on max_rolling7_stdev >= 38 condition
df_Top100withstdev[(df_Top100withstdev['max_rolling7_stdev']>=38)]['track_id'].values
# Out:
# array(['1dGr1c8CrMLDpV6mPbImSI', '6RRNNciQGZEXnqk8SQ9yv5',
#        '1pNAf6W7POwjOD8x8mWf8G', '3RauEVgRgj1IuWdJ9fDs70',
#        '2YpeDb67231RjR0MgVLzsG', '3EludUFeAoJAwSixWGG5Wg',
#        '2Rk4JlNc2TPmZe2af99d45', '43rA71bccXFGD4C8GOpIlN',
#        '7rrVN7f83kwaz2sGxoFnJY', '4pUCKHjJ4Ijewc37rRrvHn',
#        '2Gt5SmbyQjcjEqMOdEd3QE', '7Livy729zY16jBsppfYLRW',
#        '135ggzbjOogZ75IQ0LQi8r', '4vUmTMuQqjdnvlZmAH61Qk',
#        '1MkiRsYBkXbXvdiYvTTiQT', '761frfZtZ8I2g70UsjFfBK',
#        '4ZLzoOkj0MPWrTLvooIuaa', '6ocbgoVGwYJhOv1GgI9NsF',
#        '1Zyd6zQnC6XIIzmg3hP7Ot', '77iVPjxBy9Q3GgOxVE1UUA',
#        '2aI2k39nfa3KFsa4JclQzw', '2btKtacOXuMtC9WjcNRvAA',
#        '6VqZS3Wmf53pbfDBVEYvnP', '22AZDYG6qrjMFg0ceeL9X6',
       '0knRQzgvbUed6K74mX81hG', '6QBZlIxCB2lAPU2bM1ut1p']

# %%
#create is_viral column tagging the 120 songs with a 1 value if they are part of the viral_list
df['is_viral'] = df['track_id'].apply(lambda x: 1 if x in viral_list else 0)

# %%
df.head()
# Out:
#             position                track_id   track_name            artist  \
# date
# 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana       Skusta Clee
# 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita      Shawn Mendes
# 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI        Lover      Taylor Swift
# 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako  Moira Dela Torre
# 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin           Ben&Ben
#
#             streams               artist_id       artist_name  \
# date
# 2019-09-01   267548  117XFtbZPnCI1EYKjYZWJc       Skusta Clee
# 2019-09-01   259828  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes
# 2019-09-01   240408  06HL4z0CvFAxyc27GXpf02      Taylor Swift
# 2019-09-01   236726  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre
# 2019-09-01   190049  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben
#
#                           album_id  duration release_date  ...  mode  \
# ...

# %%
#count of is_viral tracks
df[df['is_viral']==1]['track_id'].nunique()
# Out:
# 120

# %%
#count of is_mainstay tracks
df[df['is_mainstay']==1]['track_id'].nunique()
# Out:
# 38

# %%
#remove duplicate column artist (retain artist_name col)
df.drop('artist',axis=1,inplace=True)

# %%
df.head()
# Out:
#             position                track_id   track_name  streams  \
# date
# 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana   267548
# 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita   259828
# 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI        Lover   240408
# 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako   236726
# 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin   190049
#
#                          artist_id       artist_name                album_id  \
# date
# 2019-09-01  117XFtbZPnCI1EYKjYZWJc       Skusta Clee  4AaygWd1ZnCzZ4ak9EM23s
# 2019-09-01  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes  0xzScN8P3hQAz3BT3YYX5w
# 2019-09-01  06HL4z0CvFAxyc27GXpf02      Taylor Swift  1NAmidJlEaVgA3MpcPFYGq
# 2019-09-01  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre  397zfeJ75BlnjfUEkgtwlG
# 2019-09-01  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben  7xCcuTA3abKwxj8HwgxP7R
#
#             duration release_date  popularity  ...  mode  speechiness  \
# ...

# %%
df.shape
# Out:
# (73200, 24)

# %%
#write to file; don't forget to revise the write path
df.to_csv('C:/Users/knocom/Eskwelabs Jupyter Notebooks/Sprint 3/get_spotify_data-master/data/merged_charts_tracks_datav2.csv', encoding='utf-8')
