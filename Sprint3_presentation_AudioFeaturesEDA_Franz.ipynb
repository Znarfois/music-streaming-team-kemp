# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Znarfois/music-streaming-team-kemp/nox/merged_charts_tracks_datav2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73200 entries, 0 to 73199
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              73200 non-null  object
#  1   position          73200 non-null  int64
#  2   track_id          73200 non-null  object
#  3   track_name        73200 non-null  object
#  4   streams           73200 non-null  int64
#  5   artist_id         73200 non-null  object
#  6   artist_name       73200 non-null  object
#  7   album_id          73200 non-null  object
#  8   duration          73200 non-null  int64
#  9   release_date      73200 non-null  object
#  10  popularity        73200 non-null  int64
#  11  danceability      73200 non-null  float64
#  12  energy            73200 non-null  float64
#  13  key               73200 non-null  int64
#  14  loudness          73200 non-null  float64
#  15  mode              73200 non-null  int64
#  16  speechiness       73200 non-null  float64
#  17  acousticness      73200 non-null  float64
#  18  instrumentalness  73200 non-null  float64
#  19  liveness          73200 non-null  float64
#  20  valence           73200 non-null  float64
#  21  tempo             73200 non-null  float64
#  22  is_mainstay       73200 non-null  int64
#  23  is_Top100         73200 non-null  int64
#  24  is_viral          73200 non-null  int64
# dtypes: float64(9), int64(9), object(7)
# memory usage: 14.0+ MB

# %%
corr = df.corr()
sns.heatmap(corr)

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date  position                track_id   track_name  streams  \
# 0 2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana   267548
# 1 2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita   259828
# 2 2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI        Lover   240408
# 3 2019-09-01         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako   236726
# 4 2019-09-01         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin   190049
#
#                 artist_id       artist_name                album_id  duration  \
# 0  117XFtbZPnCI1EYKjYZWJc       Skusta Clee  4AaygWd1ZnCzZ4ak9EM23s    304664
# 1  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes  0xzScN8P3hQAz3BT3YYX5w    190799
# 2  06HL4z0CvFAxyc27GXpf02      Taylor Swift  1NAmidJlEaVgA3MpcPFYGq    221306
# 3  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre  397zfeJ75BlnjfUEkgtwlG    269876
# 4  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben  7xCcuTA3abKwxj8HwgxP7R    227370
#
#   release_date  ...  mode  speechiness  acousticness  instrumentalness  \
# 0   07/26/2019  ...     1       0.0370        0.5450          0.000000
# 1   06/19/2019  ...     0       0.0290        0.0392          0.000000
# 2   08/23/2019  ...     1       0.0919        0.4920          0.000016
# 3   01/14/2019  ...     1       0.0289        0.8870          0.001790
# 4   05/12/2019  ...     1       0.0253        0.5060          0.000000
#
#    liveness  valence    tempo  is_mainstay  is_Top100  is_viral
# 0    0.1050    0.498  134.006            1          1         0
# 1    0.0828    0.749  116.967            1          1         0
# 2    0.1180    0.453   68.534            0          1         1
# 3    0.3220    0.366  135.525            1          1         0
# 4    0.4040    0.523   95.049            1          1         0
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#          position        streams       duration    popularity  danceability  \
# count  73200.0000   73200.000000   73200.000000  73200.000000  73200.000000
# mean     100.5000   55187.094180  231657.148634     70.265929      0.624894
# std       57.7347   44208.310362   53746.551668     14.924452      0.140069
# min        1.0000   18324.000000   41866.000000      0.000000      0.184000
# 25%       50.7500   28465.500000  195186.000000     64.000000      0.523000
# 50%      100.5000   36579.000000  217946.000000     71.000000      0.638000
# 75%      150.2500   63725.500000  261426.000000     80.000000      0.721000
# max      200.0000  514546.000000  536217.000000    100.000000      0.940000
#
#             energy          key      loudness          mode   speechiness  \
# count  73200.00000  73200.00000  73200.000000  73200.000000  73200.000000
# mean       0.52873      5.54000     -7.421862      0.779372      0.071105
# std        0.17373      3.49589      2.730869      0.414673      0.074124
# min        0.08240      0.00000    -24.250000      0.000000      0.023200
# 25%        0.40300      2.00000     -8.658000      1.000000      0.032400
# 50%        0.52900      6.00000     -7.209000      1.000000      0.043800
# 75%        0.65300      9.00000     -5.569000      1.000000      0.070500
# max        0.96900     11.00000     -0.995000      1.000000      0.555000
#
#        acousticness  instrumentalness     liveness       valence  \
# count  73200.000000      73200.000000  73200.00000  73200.000000
# mean       0.362821          0.004226      0.14868      0.439298
# std        0.273063          0.044847      0.10559      0.197342
# min        0.000002          0.000000      0.02150      0.049900
# 25%        0.116000          0.000000      0.09020      0.293000
# 50%        0.319000          0.000000      0.11000      0.424000
# 75%        0.575250          0.000007      0.16900      0.562000
# max        0.978000          0.908000      0.94400      0.973000
#
#               tempo   is_mainstay     is_Top100      is_viral
# count  73200.000000  73200.000000  73200.000000  73200.000000
# mean     117.082659      0.190000      0.825779      0.160260
# std       27.084922      0.392304      0.379302      0.366849
# min       52.572000      0.000000      0.000000      0.000000
# 25%       95.390000      0.000000      1.000000      0.000000
# 50%      115.053000      0.000000      1.000000      0.000000
# 75%      135.525000      0.000000      1.000000      0.000000
# max      207.476000      1.000000      1.000000      1.000000

# %%
df.columns
# Out:
# Index(['date', 'position', 'track_id', 'track_name', 'streams', 'artist_id',
#        'artist_name', 'album_id', 'duration', 'release_date', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'is_mainstay', 'is_Top100', 'is_viral'],
#       dtype='object')

# %%
df.shape
# Out:
# (73200, 25)

# %%
df_viral = df[df['is_viral']==1]

# %%
df_viral.head()
# Out:
#          date  position                track_id             track_name  \
# 2  2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI                  Lover
# 16 2019-09-01        17  6RRNNciQGZEXnqk8SQ9yv5  You Need To Calm Down
# 19 2019-09-01        20  1pNAf6W7POwjOD8x8mWf8G           Nobody Knows
# 26 2019-09-01        27  3RauEVgRgj1IuWdJ9fDs70                The Man
# 32 2019-09-01        33  2YpeDb67231RjR0MgVLzsG  Old Town Road - Remix
#
#     streams               artist_id   artist_name                album_id  \
# 2    240408  06HL4z0CvFAxyc27GXpf02  Taylor Swift  1NAmidJlEaVgA3MpcPFYGq
# 16   124399  06HL4z0CvFAxyc27GXpf02  Taylor Swift  1NAmidJlEaVgA3MpcPFYGq
# 19   116377  1z7b1Pr1rSlvWRzsW3HOrS          Russ  7CC9iqq2JZ3j4jF9SNNLL7
# 26   106262  06HL4z0CvFAxyc27GXpf02  Taylor Swift  1NAmidJlEaVgA3MpcPFYGq
# 32    93060  7jVv8c5Fj3E9VhNjxT4snq     Lil Nas X  4IRiXE5NROxknUSAUSjMoO
#
#     duration release_date  ...  mode  speechiness  acousticness  \
# 2     221306   08/23/2019  ...     1       0.0919       0.49200
# 16    171360   08/23/2019  ...     1       0.0553       0.00929
# 19    215555   12/23/2018  ...     1       0.4320       0.44500
# 26    190360   08/23/2019  ...     1       0.0540       0.07670
# 32    157066   06/21/2019  ...     1       0.1020       0.05330
#
#     instrumentalness  liveness  valence    tempo  is_mainstay  is_Top100  \
# 2           0.000016    0.1180    0.453   68.534            0          1
# 16          0.000000    0.0637    0.714   85.026            0          1
# 19          0.000284    0.1030    0.526  162.043            0          1
# 26          0.000000    0.0901    0.633  110.048            0          1
# 32          0.000000    0.1130    0.639  136.041            0          1
#
#     is_viral
# 2          1
# 16         1
# 19         1
# 26         1
# 32         1
#
# [5 rows x 25 columns]

# %%
#groupby to remove duplicate entries of the same track_id
df_viral.groupby(['track_id','track_name','artist_name'])[['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']].mean()
# Out:
#                                                                                                  popularity  \
# track_id               track_name                                         artist_name
# 011GTFfE8rqTRMhz5g8IAW Repeat                                             Al James                       58
# 029B34AzPVXzOQCyaJpkdH Changes                                            Lauv                            9
# 03o4HPzUwftpgAPNQSuaBS This Love Isn't Crazy                              Carly Rae Jepsen               62
# 0BaMZMMEG7GWrUYsoGw8Yg Neneng B                                           Nik Makino                     61
# 0G5qmu4TsdUH19zdcbI9Ui Vibe With Me                                       Matthaios                      69
# ...                                                                                                     ...
# 7n7mTiptQT1iNa7rMhcZS8 A Perfect Christmas - Recorded at OnQ Studios, ... Tatak Pinoy All-Stars          56
# 7rrVN7f83kwaz2sGxoFnJY Christmas in Our Hearts                            Jose Mari Chan                 58
# 7szuecWAPwGoV1e5vGu8tl In Your Eyes                                       The Weeknd                     88
# 7xapw9Oy21WpfEcib2ErSA Mistletoe                                          Justin Bieber                  65
# 7xbWAw3LMgRMn4omR5yVn3 Lose Somebody                                      Kygo                           84
#
#                                                                                                  danceability  \
# track_id               track_name                                         artist_name
# 011GTFfE8rqTRMhz5g8IAW Repeat                                             Al James                      0.844
# 029B34AzPVXzOQCyaJpkdH Changes                                            Lauv                          0.532
# 03o4HPzUwftpgAPNQSuaBS This Love Isn't Crazy                              Carly Rae Jepsen              0.632
# 0BaMZMMEG7GWrUYsoGw8Yg Neneng B                                           Nik Makino                    0.848
# 0G5qmu4TsdUH19zdcbI9Ui Vibe With Me                                       Matthaios                     0.817
# ...                                                                                                       ...
# 7n7mTiptQT1iNa7rMhcZS8 A Perfect Christmas - Recorded at OnQ Studios, ... Tatak Pinoy All-Stars         0.358
# 7rrVN7f83kwaz2sGxoFnJY Christmas in Our Hearts                            Jose Mari Chan                0.570
# 7szuecWAPwGoV1e5vGu8tl In Your Eyes                                       The Weeknd                    0.667
# 011GTFfE8rqTRMhz5g8IAW Repeat                                             Al James               120.039
# 029B34AzPVXzOQCyaJpkdH Changes                                            Lauv                   148.182
# 03o4HPzUwftpgAPNQSuaBS This Love Isn't Crazy                              Carly Rae Jepsen       117.981
# 0BaMZMMEG7GWrUYsoGw8Yg Neneng B                                           Nik Makino             117.959
# 0G5qmu4TsdUH19zdcbI9Ui Vibe With Me                                       Matthaios              100.031
# ...                                                                                                  ...
# 7n7mTiptQT1iNa7rMhcZS8 A Perfect Christmas - Recorded at OnQ Studios, ... Tatak Pinoy All-Stars  183.798
# 7rrVN7f83kwaz2sGxoFnJY Christmas in Our Hearts                            Jose Mari Chan          72.534
# 7szuecWAPwGoV1e5vGu8tl In Your Eyes                                       The Weeknd             100.021
# 7xapw9Oy21WpfEcib2ErSA Mistletoe                                          Justin Bieber          161.993
# 7xbWAw3LMgRMn4omR5yVn3 Lose Somebody                                      Kygo                   147.988
#
# [120 rows x 12 columns]

# %%
#assign to new df df_viraltracks for EDA
df_viraltracks = df_viral.groupby(['track_id','track_name','artist_name'])[['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']].mean()

# %%
#Viral DataFrame Audio Features Distribution
# for col in ['popularity', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo']:
#     sns.distplot(df_viraltracks[col], kde=True)
#     plt.title(col)
#     plt.ylabel('Frequency')
#     plt.show()

# %% [markdown]
# #Audio Features Observations for df_viraltracks:
#
# popularity = Skewed to the right, obviously most are going to have high popularity being a viral track and in the Top 200. Most are in the 70-90 range. However, what is notable is there are a number of tracks with low popularity which are still considered viral.
#
# danceability = Skewed to the right, mostly 0.5 - 0.9. Viral tracks tend to be more danceable than the usual charting tracks.
#
# energy = Almost normally distributed. Both low and high energy tracks can be viral.
#
# key = Pitch (0 = do, 2 = re, 4 = mi, 5 = fa, 7 = sol, 9 = la, 11 = ti). Well distributed.
#
# loudness = Skewed to the right, closely matches the distribution for all Spotify tracks. Majority seem to be in the -7.5dB range or higher.
#
# mode = (Major = 1; Minor = 0) More tracks are using Major modality.
#
# speechiness = (>0.66 = purely spoken words; 0.33 - 0.66 = both music and speech such as rap; <0.33 music and non-speech tracks)
# Most values are between 0 - 0.1.
#
# acousticness = (0 not acoustic; 1 acoustic) Skewed to the left, though while most viral hits are not acoustic, the remaining share of more acoustic songs (>0.12 - 0.9) is more evenly distributed frequency wise.
#
# instrumentalness = (0 has vocals; 0.5 - 1 no vocals) Majority of the tracks have vocals.
#
# liveness = (0 not live ; 0.8 - 1 high chance to be live) Majority of the tracks aren't live and probably taken from the album versions.
#
# valence = (0 sad/angry ; 1 happy/cheerful) Almost normal distribution with peak slightly to the left
#
# tempo = peaks seen from 100-125 and 150-160. Nothing below 75 and not much above 175.

# %%
#Skewness Test for df_viraltracks

# %%
from scipy.stats import skew, kurtosis

# %%
def skew_type(skewval, skewthres):
    test_skew_value = abs(skewval)-skewthres    
    if (test_skew_value > 0) & (np.sign(skewval)>0):
        return "right-tailed"
    elif  (test_skew_value > 0) & (np.sign(skewval)<0):
        return "left-tailed"
    else:
        return "approximately symmetric"

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    print("Skewness of variable %s : %0.2f (%s)" %(col, skew(df_viraltracks[col]), skew_type(skew(df_viraltracks[col]),0.1)))
# Out:
# Skewness of variable popularity : -1.70 (left-tailed)
# Skewness of variable danceability : -0.42 (left-tailed)
# Skewness of variable energy : -0.09 (approximately symmetric)
# Skewness of variable key : 0.01 (approximately symmetric)
# Skewness of variable loudness : -0.82 (left-tailed)
# Skewness of variable mode : -0.92 (left-tailed)
# Skewness of variable speechiness : 2.27 (right-tailed)
# Skewness of variable acousticness : 0.51 (right-tailed)
# Skewness of variable instrumentalness : 6.29 (right-tailed)
# Skewness of variable liveness : 1.95 (right-tailed)
# Skewness of variable valence : 0.21 (right-tailed)
# Skewness of variable tempo : 0.38 (right-tailed)

# %%
#Kurtosis Test for df_viraltracks

# %%
def kurtosis_type(kurtval, kurtthres):
    test_kurtosis_value = abs(kurtval-kurtthres)
    #in scipy's implementation, 3 is subtracted from the original definition of kurtosis
    
    if (test_kurtosis_value > 0) & (np.sign(kurtval)>0):
        return "heavy-tailed"
    elif  (test_kurtosis_value  > 0) & (np.sign(kurtval)<0):
        return "light-tailed"
    else:
        return "approximately normal"

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    print("Kurtosis of variable %s : %0.2f (%s)" %(col, kurtosis(df_viraltracks[col]), kurtosis_type(kurtosis(df_viraltracks[col]),0.1)))
# Out:
# Kurtosis of variable popularity : 2.99 (heavy-tailed)
# Kurtosis of variable danceability : -0.63 (light-tailed)
# Kurtosis of variable energy : -0.89 (light-tailed)
# Kurtosis of variable key : -1.23 (light-tailed)
# Kurtosis of variable loudness : 0.35 (heavy-tailed)
# Kurtosis of variable mode : -1.16 (light-tailed)
# Kurtosis of variable speechiness : 4.87 (heavy-tailed)
# Kurtosis of variable acousticness : -1.08 (light-tailed)
# Kurtosis of variable instrumentalness : 38.55 (heavy-tailed)
# Kurtosis of variable liveness : 4.49 (heavy-tailed)
# Kurtosis of variable valence : -0.75 (light-tailed)
# Kurtosis of variable tempo : -0.27 (light-tailed)

# %% [markdown]
# df_mainstay Section:

# %%
df_mainstay = df[df['is_mainstay']==1]

# %%
df_mainstay
# Out:
#             date  position                track_id  \
# 0     2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL
# 1     2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2
# 3     2019-09-01         4  0gDRtumoR9ZrvAlnniToMz
# 4     2019-09-01         5  5l9g7py8RCblcvbZgGQgSd
# 5     2019-09-01         6  34ob61cxp34Sf7KHK6RnSU
# ...          ...       ...                     ...
# 73145 2020-08-31       146  5UhpceEr5XmbVwyoIUIRnh
# 73147 2020-08-31       148  5f9808hpiCpuNyqqdXmpF2
# 73149 2020-08-31       150  0gDRtumoR9ZrvAlnniToMz
# 73166 2020-08-31       167  3e9HZxeyfWwjeyPAMmWSSQ
# 73167 2020-08-31       168  2RgD3eO4IIGF16rR8Ch8OV
#
#                                track_name  streams               artist_id  \
# 0                                Zebbiana   267548  117XFtbZPnCI1EYKjYZWJc
# 1                                Señorita   259828  7n2wHs1TKAczGzO7Dd2rGr
# 3                             Ikaw At Ako   236726  0rZRTXEmmPmx6gt92tBqIc
# 4                               Pagtingin   190049  4DAcJXcjX0zlQAZAPAx4Zb
# 5                      Sa Susunod Na Lang   173951  0iqkVK6sTXi7DZWWOeKy8Q
# ...                                   ...      ...                     ...
# 73145  Hanggang Kailan - Umuwi Ka Na Baby    28815  1EUmQM6xgUQLUkJVcvSdey
# 73147                               Buwan    28692  0a4r2EnsevvHCukoJ1xFwJ
# 73149                         Ikaw At Ako    28428  0rZRTXEmmPmx6gt92tBqIc
# 73166                       thank u, next    27009  66CXWjxzNUsdJxJ2JdwvnR
# 73167                        Hindi Na Nga    26948  5HIZU0JzM0AgfItVOm4E08
#
#             artist_name                album_id  duration release_date  ...  \
# 0           Skusta Clee  4AaygWd1ZnCzZ4ak9EM23s    304664   07/26/2019  ...
# 1          Shawn Mendes  0xzScN8P3hQAz3BT3YYX5w    190799   06/19/2019  ...
# 3      Moira Dela Torre  397zfeJ75BlnjfUEkgtwlG    269876   01/14/2019  ...
# 4               Ben&Ben  7xCcuTA3abKwxj8HwgxP7R    227370   05/12/2019  ...
# 5                   PDL  79UXZq6nXVVBpZgWWxb9Gq    214606   09/26/2018  ...
# ...                 ...                     ...       ...          ...  ...
# 73145   Orange & Lemons  0S0yaR1MiuHfyAZPAtChVc    261866   03/24/2005  ...
# 73147       juan karlos  2CF1utwLM2yXHMZhwFGVY1    343446   06/22/2018  ...
# 73149  Moira Dela Torre  397zfeJ75BlnjfUEkgtwlG    269876   01/14/2019  ...
# 73166     Ariana Grande  2fYhqwDWXjbpjaIJPEfKFw    207320   02/08/2019  ...
# 73167         This Band  1NbGA8Cinz1V3OmYKzq7eR    282442   09/14/2018  ...
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0         1       0.0370        0.5450          0.000000    0.1050    0.498
# 1         0       0.0290        0.0392          0.000000    0.0828    0.749
# 3         1       0.0289        0.8870          0.001790    0.3220    0.366
# 4         1       0.0253        0.5060          0.000000    0.4040    0.523
# 5         0       0.1200        0.1040          0.000000    0.0899    0.721
# ...     ...          ...           ...               ...       ...      ...
# 73145     1       0.0296        0.1160          0.000002    0.2260    0.399
# 73147     1       0.0400        0.4470          0.000171    0.0902    0.360
# 73149     1       0.0289        0.8870          0.001790    0.3220    0.366
# 73166     1       0.0658        0.2290          0.000000    0.1010    0.412
# 73167     1       0.0334        0.0877          0.000029    0.1240    0.108
#
#          tempo  is_mainstay  is_Top100  is_viral
# 0      134.006            1          1         0
# 1      116.967            1          1         0
# 3      135.525            1          1         0
# 4       95.049            1          1         0
# 5       84.929            1          1         0
# ...        ...          ...        ...       ...
# 73145  146.433            1          1         0
# 73147  126.008            1          1         0
# 73149  135.525            1          1         0
# 73166  106.966            1          1         0
# 73167  136.818            1          1         0
#
# [13908 rows x 25 columns]

# %%
df_mainstay.groupby(['track_id','track_name','artist_name'])[['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumental
# 0Eqg0CQ7bK3RQIMPw1A7pl Malibu Nights                     LANY                  74.002
# 0HZ3OUVrGHxttD2EuHqRm3 The Day You Said Goodnight        Hale                 134.263
# 0Vmk6Ebk4QBq7r0VAz2a6s Bakit Ba Ikaw                     Michael Pangilinan   119.903
# 0gDRtumoR9ZrvAlnniToMz Ikaw At Ako                       Moira Dela Torre     135.525
# 0hVXuCcriWRGvwMV1r5Yn9 I Don't Care (with Justin Bieber) Ed Sheeran           101.956
# 135ggzbjOogZ75IQ0LQi8r Ang Huling El Bimbo               Eraserheads           89.497
# 1X4l4i472kW5ofFP8Xo0x0 Sana                              I Belong to the Zoo  126.887
# 1rgnBhdG2JDFTbYkYRZAku Dance Monkey                      Tones And I           98.078
# 1yDiru08Q6omDOGkZMPnei Maybe The Night                   Ben&Ben               74.050

# %%
#assign to new df df_mainstaytracks for EDA
df_mainstaytracks = df_mainstay.groupby(['track_id','track_name','artist_name'])[['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'streams',
       'liveness', 'valence', 'tempo']].mean()

# %%
# #Mainstay DataFrame Audio Features Distribution
# for col in ['popularity', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo']:
#     sns.distplot(df_mainstaytracks[col], kde=True)
#     plt.title(col)
#     plt.ylabel('Frequency')
#     plt.show()

# %% [markdown]
# #Audio Features Observations for df_viraltracks:
#
# popularity = Mainstays are quite centered between the 60-90 range in popularity.
#
# danceability = Almost normally distributed. Range is between 0.36 - 0.82. Peak at 0.7 range. Mainstay tracks tend to be more danceable.
#
# energy = Almost normally distributed. Both low and high energy tracks can be mainstays. Peak is at 0.5.
#
# key = Pitch (0 = do, 2 = re, 4 = mi, 5 = fa, 7 = sol, 9 = la, 11 = ti). Well distributed.
#
# loudness = Skewed to the right, closely matches the distribution for all Spotify tracks. Though there is a notable dip in the -10 dB range.
#
# mode = (Major = 1; Minor = 0) Even more tracks are using Major (1) modality.
#
# speechiness = (>0.66 = purely spoken words; 0.33 - 0.66 = both music and speech such as rap; <0.33 music and non-speech tracks)
# Most values are between 0 - 0.1.
#
# acousticness = (0 not acoustic; 1 acoustic) Skewed to the left, but not by much. Songs appear to be varied in terms of acousticness.
#
# instrumentalness = (0 has vocals; 0.5 - 1 no vocals) Majority of the tracks have vocals. In fact, no mainstay track registered a value of above 0.3
#
# liveness = (0 not live ; 0.8 - 1 high chance to be live) Majority of the tracks aren't live and probably taken from the album versions.
#
# valence = (0 sad/angry ; 1 happy/cheerful) Almost normal distribution with peak slightly to the left
#
# tempo = peaks seen from 125 - 140. Nothing below 75 and nothing above 162.

# %%
#Skewness Test for df_mainstaytracks

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    print("Skewness of variable %s : %0.2f (%s)" %(col, skew(df_mainstaytracks[col]), skew_type(skew(df_mainstaytracks[col]),0.1)))
# Out:
# Skewness of variable popularity : 0.72 (right-tailed)
# Skewness of variable danceability : -0.08 (approximately symmetric)
# Skewness of variable energy : 0.04 (approximately symmetric)
# Skewness of variable key : -0.05 (approximately symmetric)
# Skewness of variable loudness : -0.49 (left-tailed)
# Skewness of variable mode : -1.63 (left-tailed)
# Skewness of variable speechiness : 2.35 (right-tailed)
# Skewness of variable acousticness : 0.20 (right-tailed)
# Skewness of variable instrumentalness : 5.84 (right-tailed)
# Skewness of variable liveness : 2.09 (right-tailed)
# Skewness of variable valence : 0.21 (right-tailed)
# Skewness of variable tempo : 0.02 (approximately symmetric)

# %%
#Kurtosis Test for df_mainstaytracks

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    print("Kurtosis of variable %s : %0.2f (%s)" %(col, kurtosis(df_mainstaytracks[col]), kurtosis_type(kurtosis(df_mainstaytracks[col]),0.1)))
# Out:
# Kurtosis of variable popularity : -0.75 (light-tailed)
# Kurtosis of variable danceability : -0.92 (light-tailed)
# Kurtosis of variable energy : 0.17 (heavy-tailed)
# Kurtosis of variable key : -0.85 (light-tailed)
# Kurtosis of variable loudness : -0.55 (light-tailed)
# Kurtosis of variable mode : 0.65 (heavy-tailed)
# Kurtosis of variable speechiness : 4.88 (heavy-tailed)
# Kurtosis of variable acousticness : -1.41 (light-tailed)
# Kurtosis of variable instrumentalness : 32.38 (heavy-tailed)
# Kurtosis of variable liveness : 4.37 (heavy-tailed)
# Kurtosis of variable valence : -0.27 (light-tailed)
# Kurtosis of variable tempo : -1.00 (light-tailed)

# %% [markdown]
# df_BenandBen Section:

# %%
df_BenandBen = df[df['artist_name']=='Ben&Ben']

# %%
df_BenandBen
# Out:
#             date  position                track_id          track_name  \
# 4     2019-09-01         5  5l9g7py8RCblcvbZgGQgSd           Pagtingin
# 13    2019-09-01        14  1yDiru08Q6omDOGkZMPnei     Maybe The Night
# 21    2019-09-01        22  3WUEs51GpcvlgU7lehLgLh        Kathang Isip
# 97    2019-09-01        98  6wdCelHrPh7UfliNjwRTUv              Leaves
# 204   2019-09-02         5  5l9g7py8RCblcvbZgGQgSd           Pagtingin
# ...          ...       ...                     ...                 ...
# 73039 2020-08-31        40  5l9g7py8RCblcvbZgGQgSd           Pagtingin
# 73053 2020-08-31        54  6wdCelHrPh7UfliNjwRTUv              Leaves
# 73064 2020-08-31        65  3X9c4tBzSdGhlO4Fx3WYgW            Lifetime
# 73073 2020-08-31        74  4rG3h1QwgjSSWz8EIjCFrm           Araw-Araw
# 73105 2020-08-31       106  0luyrm1L6gjtoLekHOf67t  Masyado Pang Maaga
#
#        streams               artist_id artist_name                album_id  \
# 4       190049  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  7xCcuTA3abKwxj8HwgxP7R
# 13      132927  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  6LhZ3QMHGJeTes9cCTxK8e
# 21      112781  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  4nQxblVnnFPehg9ujzdJ8L
# 97       37752  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  5Yl1Bi501CuE72jaVK4e3y
# 204     194044  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  7xCcuTA3abKwxj8HwgxP7R
# ...        ...                     ...         ...                     ...
# 73039    70173  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  7xCcuTA3abKwxj8HwgxP7R
# 73053    57175  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  5Yl1Bi501CuE72jaVK4e3y
# 73064    51330  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  277CpjwmcdLZsHwXpj9D8H
# 73073    45518  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  7xCcuTA3abKwxj8HwgxP7R
# 73105    35046  4DAcJXcjX0zlQAZAPAx4Zb     Ben&Ben  75Y2NZzYQyYpxusG8e0ZeM
#
#        duration release_date  ...  mode  speechiness  acousticness  \
# 4        227370   05/12/2019  ...     1       0.0253         0.506
# 13       217197   10/27/2017  ...     1       0.0367         0.113
# 21       318814   06/23/2017  ...     1       0.0301         0.776
# 97       310708   03/31/2017  ...     1       0.0372         0.913
# 204      227370   05/12/2019  ...     1       0.0253         0.506
# ...         ...          ...  ...   ...          ...           ...
# 73039    227370   05/12/2019  ...     1       0.0253         0.506
# 73053    310708   03/31/2017  ...     1       0.0372         0.913
# 73064    171527   06/04/2020  ...     1       0.0316         0.292
# 73073    313951   05/12/2019  ...     1       0.0295         0.582
# 73105    306204   11/01/2019  ...     1       0.0295         0.458
#
#        instrumentalness  liveness  valence    tempo  is_mainstay  is_Top100  \
# 4              0.000000    0.4040    0.523   95.049            1          1
# 13             0.000049    0.1140    0.498   74.050            1          1
# 21             0.000005    0.1520    0.295  126.921            1          1
# 97             0.000000    0.0891    0.205  118.313            1          1
# 204            0.000000    0.4040    0.523   95.049            1          1
# ...                 ...       ...      ...      ...          ...        ...
# 73039          0.000000    0.4040    0.523   95.049            1          1
# 73053          0.000000    0.0891    0.205  118.313            1          1
# 73064          0.000010    0.3930    0.401  179.998            0          1
# 73073          0.000000    0.2340    0.224  140.903            0          1
# 73105          0.000000    0.1100    0.310  140.051            0          1
#
#        is_viral
# 4             0
# 13            0
# 21            0
# 97            0
# 204           0
# ...         ...
# 73039         0
# 73053         0
# 73064         0
# 73073         0
# 73105         0
#
# [3212 rows x 25 columns]

# %%
df_BenandBen.groupby(['track_id','track_name','artist_name'])[['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']].mean()
# Out:
#                                                                popularity  \
# track_id               track_name                 artist_name
# 0luyrm1L6gjtoLekHOf67t Masyado Pang Maaga         Ben&Ben              65
# 1EEsKj8lQKZwaFXJ5GFsdk War                        Ben&Ben              57
# 1PUWUlqe6m5HqX754lN3Bs Mitsa (Salamat)            Ben&Ben              57
# 1fXHTDYsJiFOjVWITaFp1j Ride Home                  Ben&Ben              61
# 1yDiru08Q6omDOGkZMPnei Maybe The Night            Ben&Ben              71
# 2Mo4pOpCYXOu33856sMQLh Make It With You           Ben&Ben              71
# 37WFUZgkjJKLaISRcX0269 Doors                      Ben&Ben              61
# 3PgjBOoA5OytNGkglObpOd Sa Susunod na Habang Buhay Ben&Ben              71
# 3WUEs51GpcvlgU7lehLgLh Kathang Isip               Ben&Ben              71
# 1PUWUlqe6m5HqX754lN3Bs Mitsa (Salamat)            Ben&Ben      122.366
# 1fXHTDYsJiFOjVWITaFp1j Ride Home                  Ben&Ben      114.110
# 1yDiru08Q6omDOGkZMPnei Maybe The Night            Ben&Ben       74.050
# 2Mo4pOpCYXOu33856sMQLh Make It With You           Ben&Ben       86.877
# 37WFUZgkjJKLaISRcX0269 Doors                      Ben&Ben       74.979
# 3PgjBOoA5OytNGkglObpOd Sa Susunod na Habang Buhay Ben&Ben      177.158
# 3WUEs51GpcvlgU7lehLgLh Kathang Isip               Ben&Ben      126.921
# 3X9c4tBzSdGhlO4Fx3WYgW Lifetime                   Ben&Ben      179.998
# 3nmRSlzR7xtAo95GjfIahZ Bibingka                   Ben&Ben      204.074
# 4SQ3HwsAiGTikY7gOAybwH Fall                       Ben&Ben      149.828
# 4rG3h1QwgjSSWz8EIjCFrm Araw-Araw                  Ben&Ben      140.903
# 5l9g7py8RCblcvbZgGQgSd Pagtingin                  Ben&Ben       95.049
# 6wdCelHrPh7UfliNjwRTUv Leaves                     Ben&Ben      118.313
# 74jVIbukOhR0Am7YXKiJMM Nakikinig Ka Ba Sa Akin    Ben&Ben      155.880

# %%
#assign to new df df_viraltracks for EDA
df_BenandBentracks = df_BenandBen.groupby(['track_id','track_name','artist_name'])[['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']].mean()

# %% [markdown]
# # Comparing Main Dataframe with Viral Tracks

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    sns.distplot(df[col], kde=True)
    sns.distplot(df_viraltracks[col], kde=True)
#     sns.distplot(df_mainstaytracks[col], kde=True)
    plt.title(col)
    plt.ylabel('Frequency')
#     sns.distplot(df_BenandBentracks[col], kde=True)
    plt.show()
# Out:
# C:\Users\me\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Comparing main Dataframe with Mainstay Tracks

# %%
#Viral DataFrame Audio Features Distribution
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    sns.distplot(df[col], kde=True)
#     sns.distplot(df_viraltracks[col], kde=True)
    sns.distplot(df_mainstaytracks[col], kde=True)
    plt.title(col)
    plt.ylabel('Frequency')
#     sns.distplot(df_BenandBentracks[col], kde=True)
    plt.show()
# Out:
# C:\Users\me\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\me\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Comparing main dataframe with Ben&Ben tracks

# %%
#Viral DataFrame Audio Features Distribution
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    sns.distplot(df[col], kde=True)
# ?     sns.distplot(df_viraltracks[col], kde=True)   sns.distplot(df_mainstaytracks[col], kde=True)
    plt.title(col)
    plt.ylabel('Frequency')
    sns.distplot(df_BenandBentracks[col], kde=True)
    plt.show()
# Out:
# C:\Users\me\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\me\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #Audio Features Observations for df_BenandBentracks:
#
# popularity = Ben & Ben songs are skewed to the right and are popular. Their tracks fall between the 57-71 range.
#
# danceability = Almost normally distributed. Good mix in terms of danceability given the range of 0.31 - 0.67.
#
# energy = Slightly skewed to the right. Ben&Ben has more above average energy tracks, but nothing too high.
#
# key = Pitch (0 = do, 2 = re, 4 = mi, 5 = fa, 7 = sol, 9 = la, 11 = ti). Well distributed.
#
# loudness = Slightly skewed to the right, though it is almost evenly distributed.
#
# mode = All tracks are using 1 (Major) modality.
#
# speechiness = (>0.66 = purely spoken words; 0.33 - 0.66 = both music and speech such as rap; <0.33 music and non-speech tracks)
# Most values are around the 0.3 mark, which means most of their music are still focused on instruments but there appears to be a song with a higher value of 0.485. (Make It With You)
#
# acousticness = (0 not acoustic; 1 acoustic) Skewed to the right, they have more tracks that are more acoustic sounding.
#
# instrumentalness = (0 has vocals; 0.5 - 1 no vocals) All of the tracks have vocals as there's nothing that registered above 0.005 in insturmentalness.
#
# liveness = (0 not live ; 0.8 - 1 high chance to be live) Majority of the tracks aren't live and probably taken from the album versions. One track registered 0.39 in liveness (Lifetime - the sounds of the starting few seconds is similar to that of a live track) Another registered 0.4 in liveness (Pagtingin, though i'm not sure why)
#
# valence = (0 sad/angry ; 1 happy/cheerful) Slightly skewed to the left. Majority of the songs are within 0.5 valence and below which means more of their songs can be considered sadder.
#
# tempo = majority within 75-150 range.

# %%
#Skewness Test for df_BenandBentracks
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    print("Skewness of variable %s : %0.2f (%s)" %(col, skew(df_BenandBentracks[col]), skew_type(skew(df_BenandBentracks[col]),0.1)))
# Out:
# Skewness of variable popularity : -0.40 (left-tailed)
# Skewness of variable danceability : -0.00 (approximately symmetric)
# Skewness of variable energy : -0.18 (left-tailed)
# Skewness of variable key : 0.14 (right-tailed)
# Skewness of variable loudness : -0.16 (left-tailed)
# Skewness of variable mode : 0.00 (approximately symmetric)
# Skewness of variable speechiness : 1.44 (right-tailed)
# Skewness of variable acousticness : -0.18 (left-tailed)
# Skewness of variable instrumentalness : 3.52 (right-tailed)
# Skewness of variable liveness : 1.57 (right-tailed)
# Skewness of variable valence : 0.16 (right-tailed)
# Skewness of variable tempo : 0.30 (right-tailed)

# %%
#Kurtosis Test for df_BenandBentracks
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    print("Kurtosis of variable %s : %0.2f (%s)" %(col, kurtosis(df_BenandBentracks[col]), kurtosis_type(kurtosis(df_BenandBentracks[col]),0.1)))
# Out:
# Kurtosis of variable popularity : -1.47 (light-tailed)
# Kurtosis of variable danceability : -0.98 (light-tailed)
# Kurtosis of variable energy : -0.76 (light-tailed)
# Kurtosis of variable key : -1.29 (light-tailed)
# Kurtosis of variable loudness : -0.60 (light-tailed)
# Kurtosis of variable mode : -3.00 (light-tailed)
# Kurtosis of variable speechiness : 2.37 (heavy-tailed)
# Kurtosis of variable acousticness : -1.20 (light-tailed)
# Kurtosis of variable instrumentalness : 10.62 (heavy-tailed)
# Kurtosis of variable liveness : 1.27 (heavy-tailed)
# Kurtosis of variable valence : -1.31 (light-tailed)
# Kurtosis of variable tempo : -0.82 (light-tailed)

# %%
df_BenandBen.groupby(['track_id','track_name', 'artist_name'])['streams'].sum().sort_values(ascending=False)
# Out:
# track_id                track_name                  artist_name
# 5l9g7py8RCblcvbZgGQgSd  Pagtingin                   Ben&Ben        58484656
# 3WUEs51GpcvlgU7lehLgLh  Kathang Isip                Ben&Ben        38663329
# 2Mo4pOpCYXOu33856sMQLh  Make It With You            Ben&Ben        37101290
# 1yDiru08Q6omDOGkZMPnei  Maybe The Night             Ben&Ben        33619785
# 0luyrm1L6gjtoLekHOf67t  Masyado Pang Maaga          Ben&Ben        29873165
# 4rG3h1QwgjSSWz8EIjCFrm  Araw-Araw                   Ben&Ben        24589104
# 6wdCelHrPh7UfliNjwRTUv  Leaves                      Ben&Ben        21437597
# 3PgjBOoA5OytNGkglObpOd  Sa Susunod na Habang Buhay  Ben&Ben        21434624
# 3X9c4tBzSdGhlO4Fx3WYgW  Lifetime                    Ben&Ben         8864755
# 1fXHTDYsJiFOjVWITaFp1j  Ride Home                   Ben&Ben         7295572
# 74jVIbukOhR0Am7YXKiJMM  Nakikinig Ka Ba Sa Akin     Ben&Ben         5027588
# 4SQ3HwsAiGTikY7gOAybwH  Fall                        Ben&Ben         4135664
# 37WFUZgkjJKLaISRcX0269  Doors                       Ben&Ben         3791933
# 3nmRSlzR7xtAo95GjfIahZ  Bibingka                    Ben&Ben         1414986
# 1PUWUlqe6m5HqX754lN3Bs  Mitsa (Salamat)             Ben&Ben          886245
# 1EEsKj8lQKZwaFXJ5GFsdk  War                         Ben&Ben           40905
# Name: streams, dtype: int64

# %%
df_viral.groupby(['track_id','track_name', 'artist_name'])['streams'].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-106-a73bd3b896e2> in <module>
# ----> 1 df_viral.groupby(['track_id','track_name', 'artist_name'])['streams'].sum().sort_values(ascending=False)[df_viral['artist_name']=="Ben&Ben"]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     906
#     907         if com.is_bool_indexer(key):
# --> 908             key = check_bool_indexer(self.index, key)
#     909
#     910         return self._get_with(key)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2315         mask = isna(result._values)
#    2316         if mask.any():
# -> 2317             raise IndexingError(
#    2318                 "Unalignable boolean Series provided as "
#    2319                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
df_mainstaytracks.groupby(['track_id','track_name', 'artist_name'])['streams'].sum().sort_values(ascending=False)
# Out:
# track_id                track_name                                                         artist_name
# 5l9g7py8RCblcvbZgGQgSd  Pagtingin                                                          Ben&Ben                159794.142077
# 7qEHsqek33rTcFNT9PFqLf  Someone You Loved                                                  Lewis Capaldi          125445.628415
# 6IdEQ3HUseBeRUYFSzSMdL  Zebbiana                                                           Skusta Clee            115068.663934
# 3WUEs51GpcvlgU7lehLgLh  Kathang Isip                                                       Ben&Ben                105637.510929
# 34ob61cxp34Sf7KHK6RnSU  Sa Susunod Na Lang                                                 PDL                     97555.740437
# 1yDiru08Q6omDOGkZMPnei  Maybe The Night                                                    Ben&Ben                 91857.336066
# 3e9HZxeyfWwjeyPAMmWSSQ  thank u, next                                                      Ariana Grande           32916.142077
# Name: streams, dtype: float64

# %%
df3 = pd.read_csv('data/merged_charts_tracks_datav3.csv')

# %%
df3.head()
# Out:
#                  track_id        date  position             track_name  \
# 0  00mBzIWv5gHOYxwuEJXjOG  2019-09-01        38  Sa Ngalan Ng Pag-Ibig
# 1  00mBzIWv5gHOYxwuEJXjOG  2019-09-02        39  Sa Ngalan Ng Pag-Ibig
# 2  00mBzIWv5gHOYxwuEJXjOG  2019-09-03        37  Sa Ngalan Ng Pag-Ibig
# 3  00mBzIWv5gHOYxwuEJXjOG  2019-09-04        35  Sa Ngalan Ng Pag-Ibig
# 4  00mBzIWv5gHOYxwuEJXjOG  2019-09-05        33  Sa Ngalan Ng Pag-Ibig
#
#    streams               artist_id      artist_name                album_id  \
# 0    84905  4qFxP3qN9GsnZDOkAE6x2m  December Avenue  7xconhHQKj7Be4P2KvUmFz
# 1    85890  4qFxP3qN9GsnZDOkAE6x2m  December Avenue  7xconhHQKj7Be4P2KvUmFz
# 2    90874  4qFxP3qN9GsnZDOkAE6x2m  December Avenue  7xconhHQKj7Be4P2KvUmFz
# 3    95429  4qFxP3qN9GsnZDOkAE6x2m  December Avenue  7xconhHQKj7Be4P2KvUmFz
# 4    98197  4qFxP3qN9GsnZDOkAE6x2m  December Avenue  7xconhHQKj7Be4P2KvUmFz
#
#    duration release_date  ...  predicted_genre_id  predicted_genre  \
# 0    285138   04/29/2017  ...                   2       electronic
# 1    285138   04/29/2017  ...                   2       electronic
# 2    285138   04/29/2017  ...                   2       electronic
# 3    285138   04/29/2017  ...                   2       electronic
# 4    285138   04/29/2017  ...                   2       electronic
#
#    predicted_genre_prob  predicted_classical_prob  predicted_country_prob  \
# 0              0.542857                       0.0                0.257143
# 1              0.542857                       0.0                0.257143
# 2              0.542857                       0.0                0.257143
# 3              0.542857                       0.0                0.257143
# 4              0.542857                       0.0                0.257143
#
#    predicted_electronic_prob  predicted_folk_prob  \
# 0                   0.542857             0.085714
# 1                   0.542857             0.085714
# 2                   0.542857             0.085714
# 3                   0.542857             0.085714
# 4                   0.542857             0.085714
#
#    predicted_hiphoprapcons_prob  predicted_jazz_prob  predicted_rock_prob
# 0                      0.028571                  0.0             0.085714
# 1                      0.028571                  0.0             0.085714
# 2                      0.028571                  0.0             0.085714
# 3                      0.028571                  0.0             0.085714
# 4                      0.028571                  0.0             0.085714
#
# [5 rows x 35 columns]

# %%
df3.shape
# Out:
# (73200, 35)

# %%
df3.columns
# Out:
# Index(['track_id', 'date', 'position', 'track_name', 'streams', 'artist_id',
#        'artist_name', 'album_id', 'duration', 'release_date', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'is_mainstay', 'is_Top100', 'is_viral', 'predicted_genre_id',
#        'predicted_genre', 'predicted_genre_prob', 'predicted_classical_prob',
#        'predicted_country_prob', 'predicted_electronic_prob',
#        'predicted_folk_prob', 'predicted_hiphoprapcons_prob',
#        'predicted_jazz_prob', 'predicted_rock_prob'],
#       dtype='object')

# %%
df3[['track_id', 'track_name', 'artist_name', 'predicted_genre']]
# Out:
#                      track_id                    track_name      artist_name  \
# 0      00mBzIWv5gHOYxwuEJXjOG         Sa Ngalan Ng Pag-Ibig  December Avenue
# 1      00mBzIWv5gHOYxwuEJXjOG         Sa Ngalan Ng Pag-Ibig  December Avenue
# 2      00mBzIWv5gHOYxwuEJXjOG         Sa Ngalan Ng Pag-Ibig  December Avenue
# 3      00mBzIWv5gHOYxwuEJXjOG         Sa Ngalan Ng Pag-Ibig  December Avenue
# 4      00mBzIWv5gHOYxwuEJXjOG         Sa Ngalan Ng Pag-Ibig  December Avenue
# ...                       ...                           ...              ...
# 73195  7ytR5pFWmSjzHJIeQkgog4  ROCKSTAR (feat. Roddy Ricch)           DaBaby
# 73196  7ytR5pFWmSjzHJIeQkgog4  ROCKSTAR (feat. Roddy Ricch)           DaBaby
# 73197  7zFBtYAVURF3bUVqEQ6UUu                           ICY             ITZY
# 73198  7zFBtYAVURF3bUVqEQ6UUu                           ICY             ITZY
# 73199  7zFBtYAVURF3bUVqEQ6UUu                           ICY             ITZY
#
#       predicted_genre
# 0          electronic
# 1          electronic
# 2          electronic
# 3          electronic
# 4          electronic
# ...               ...
# 73195   hiphoprapcons
# 73196   hiphoprapcons
# 73197   hiphoprapcons
# 73198   hiphoprapcons
# 73199   hiphoprapcons
#
# [73200 rows x 4 columns]

# %%
df3.groupby('predicted_genre')

# %%
df3
# Out:
#                      track_id        date  position  \
# 0      00mBzIWv5gHOYxwuEJXjOG  2019-09-01        38
# 1      00mBzIWv5gHOYxwuEJXjOG  2019-09-02        39
# 2      00mBzIWv5gHOYxwuEJXjOG  2019-09-03        37
# 3      00mBzIWv5gHOYxwuEJXjOG  2019-09-04        35
# 4      00mBzIWv5gHOYxwuEJXjOG  2019-09-05        33
# ...                       ...         ...       ...
# 73195  7ytR5pFWmSjzHJIeQkgog4  2020-08-30        48
# 73196  7ytR5pFWmSjzHJIeQkgog4  2020-08-31        52
# 73197  7zFBtYAVURF3bUVqEQ6UUu  2019-09-01       161
# 73198  7zFBtYAVURF3bUVqEQ6UUu  2019-09-08       195
# 73199  7zFBtYAVURF3bUVqEQ6UUu  2019-09-15       185
#
#                          track_name  streams               artist_id  \
# 0             Sa Ngalan Ng Pag-Ibig    84905  4qFxP3qN9GsnZDOkAE6x2m
# 1             Sa Ngalan Ng Pag-Ibig    85890  4qFxP3qN9GsnZDOkAE6x2m
# 2             Sa Ngalan Ng Pag-Ibig    90874  4qFxP3qN9GsnZDOkAE6x2m
# 3             Sa Ngalan Ng Pag-Ibig    95429  4qFxP3qN9GsnZDOkAE6x2m
# 4             Sa Ngalan Ng Pag-Ibig    98197  4qFxP3qN9GsnZDOkAE6x2m
# ...                             ...      ...                     ...
# 73195  ROCKSTAR (feat. Roddy Ricch)    57200  4r63FhuTkUYltbVAg5TQnk
# 73196  ROCKSTAR (feat. Roddy Ricch)    60862  4r63FhuTkUYltbVAg5TQnk
# 73197                           ICY    26993  2KC9Qb60EaY0kW4eH68vr3
# 73198                           ICY    24025  2KC9Qb60EaY0kW4eH68vr3
# 73199                           ICY    24404  2KC9Qb60EaY0kW4eH68vr3
#
#            artist_name                album_id  duration release_date  ...  \
# 0      December Avenue  7xconhHQKj7Be4P2KvUmFz    285138   04/29/2017  ...
# 1      December Avenue  7xconhHQKj7Be4P2KvUmFz    285138   04/29/2017  ...
# 2      December Avenue  7xconhHQKj7Be4P2KvUmFz    285138   04/29/2017  ...
# 3      December Avenue  7xconhHQKj7Be4P2KvUmFz    285138   04/29/2017  ...
# 4      December Avenue  7xconhHQKj7Be4P2KvUmFz    285138   04/29/2017  ...
# ...                ...                     ...       ...          ...  ...
# 73195           DaBaby  623PL2MBg50Br5dLXC9E9e    181733   04/17/2020  ...
# 73196           DaBaby  623PL2MBg50Br5dLXC9E9e    181733   04/17/2020  ...
# 73197             ITZY  2y2Nuvvw5xNDYOunTSsgf1    191142   07/29/2019  ...
# 73198             ITZY  2y2Nuvvw5xNDYOunTSsgf1    191142   07/29/2019  ...
# 73199             ITZY  2y2Nuvvw5xNDYOunTSsgf1    191142   07/29/2019  ...
#
#        predicted_genre_id  predicted_genre  predicted_genre_prob  \
# 0                       2       electronic              0.542857
# 1                       2       electronic              0.542857
# 2                       2       electronic              0.542857
# 3                       2       electronic              0.542857
# 4                       2       electronic              0.542857
# ...                   ...              ...                   ...
# 73195                   4    hiphoprapcons              0.714286
# 73196                   4    hiphoprapcons              0.714286
# 73197                   4    hiphoprapcons              0.371429
# 73198                   4    hiphoprapcons              0.371429
# 73199                   4    hiphoprapcons              0.371429
#
#        predicted_classical_prob  predicted_country_prob  \
# 0                           0.0                0.257143
# 1                           0.0                0.257143
# 2                           0.0                0.257143
# 3                           0.0                0.257143
# 4                           0.0                0.257143
# ...                         ...                     ...
# 73195                       0.0                0.171429
# 73196                       0.0                0.171429
# 73197                       0.0                0.285714
# 73198                       0.0                0.285714
# 73199                       0.0                0.285714
#
#        predicted_electronic_prob  predicted_folk_prob  \
# 0                       0.542857             0.085714
# 1                       0.542857             0.085714
# 2                       0.542857             0.085714
# 3                       0.542857             0.085714
# 4                       0.542857             0.085714
# ...                          ...                  ...
# 73195                   0.000000             0.028571
# 73196                   0.000000             0.028571
# 73197                   0.114286             0.057143
# 73198                   0.114286             0.057143
# 73199                   0.114286             0.057143
#
#        predicted_hiphoprapcons_prob  predicted_jazz_prob  predicted_rock_prob
# 0                          0.028571             0.000000             0.085714
# 1                          0.028571             0.000000             0.085714
# 2                          0.028571             0.000000             0.085714
# 3                          0.028571             0.000000             0.085714
# 4                          0.028571             0.000000             0.085714
# ...                             ...                  ...                  ...
# 73195                      0.714286             0.057143             0.028571
# 73196                      0.714286             0.057143             0.028571
# 73197                      0.371429             0.000000             0.171429
# 73198                      0.371429             0.000000             0.171429
# 73199                      0.371429             0.000000             0.171429
#
# [73200 rows x 35 columns]

# %%
df3.corr()
# Out:
#   File "<ipython-input-105-dde69d0cbafb>", line 1
#     df3.corr()??
#               ^
# SyntaxError: invalid syntax

# %%
# Out:
# Object `jupyterlab_go_to_definition` not found.

# %%
jupyter labextension install @krassowski/jupyterlab_go_to_definition
