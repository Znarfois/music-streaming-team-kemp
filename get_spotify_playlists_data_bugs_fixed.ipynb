# %%
import numpy as np
import pandas as pd

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import keyring
import time

# %% [markdown]
# ## 0. Setup Spotipy credentials and query wrapper

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=keyring.get_password('spotify', 'cid'),
                                                      client_secret=keyring.get_password('spotify', 'secret') )
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# Set keyword

# %%
KEYWORD = 'electronic songs'

# %% [markdown]
# ## 1. Search for the top N playlists for keyword

# %% [markdown]
# ##### View the structure of a search query

# %%
results = sp.search(q=KEYWORD, type='playlist', market='PH')

# %%
results
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=electronic+songs&type=playlist&market=PH&offset=0&limit=10',
#   'items': [{'collaborative': False,
#     'description': 'Top 80s &amp; 90s Dance Songs. Classic Dance Music Hits &amp; Euro Dance from Eighties &amp; Nineties',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/5RFz5RUGbPCaS0yObBrD2z'},
#     'href': 'https://api.spotify.com/v1/playlists/5RFz5RUGbPCaS0yObBrD2z',
#     'id': '5RFz5RUGbPCaS0yObBrD2z',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebbe84f0c696e21602e15eb6208',
#       'width': None}],
#     'name': "Dance Music Hits 80s 90s | Best Dance Electronic Songs of the 80's & 90's",
#     'owner': {'display_name': 'Listanauta',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/listanauta'},
#      'href': 'https://api.spotify.com/v1/users/listanauta',
#      'id': 'listanauta',
#      'type': 'user',
#      'uri': 'spotify:user:listanauta'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NDcsMGExMTU3OGI0NjRlNDY0NjhlNGZmNmYzOTUwODFiNTMxM2NiN2JlNQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/5RFz5RUGbPCaS0yObBrD2z/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:5RFz5RUGbPCaS0yObBrD2z'},
#    {'collaborative': False,
#     'description': 'Best Songs for Gym Workout Motivation. Electro Dance Music, Electronic Pop, Dance &amp; More Music Hits',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0nLAD9xRWqG5Ck3lnfV75H'},
#     'href': 'https://api.spotify.com/v1/playlists/0nLAD9xRWqG5Ck3lnfV75H',
#     'id': '0nLAD9xRWqG5Ck3lnfV75H',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebbf6a2528c36387af02fc0fe53',
#       'width': None}],
#     'name': 'Gym Workout Music. Hits of EDM Dance & Electronic Songs',
#     'owner': {'display_name': 'Listanauta',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/listanauta'},
#      'href': 'https://api.spotify.com/v1/users/listanauta',
#      'id': 'listanauta',
#      'type': 'user',
#      'uri': 'spotify:user:listanauta'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTg5LDY5YTFiOWNlZjMxNjhlNGMwNTcyNWVjYTQ4ZmQyMGQxM2RmZWE0NmY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0nLAD9xRWqG5Ck3lnfV75H/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0nLAD9xRWqG5Ck3lnfV75H'},
#    {'collaborative': False,
#     'description': 'In the next year, you will be able to find this playlist with the next title: Top 50 Summer Electronic Songs of All Time (updated in July 2021)',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0HtJC43c97s2ILhapbQHYk'},
#     'href': 'https://api.spotify.com/v1/playlists/0HtJC43c97s2ILhapbQHYk',
#     'id': '0HtJC43c97s2ILhapbQHYk',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27304bfd5a5fd5aa6ca648f66aaab67616d0000b273495ce6da9aeb159e94eaa453ab67616d0000b273c3055e5c1073d11b1ae2e553ab67616d0000b273f30d6575306b5502236a429f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27304bfd5a5fd5aa6ca648f66aaab67616d0000b273495ce6da9aeb159e94eaa453ab67616d0000b273c3055e5c1073d11b1ae2e553ab67616d0000b273f30d6575306b5502236a429f',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27304bfd5a5fd5aa6ca648f66aaab67616d0000b273495ce6da9aeb159e94eaa453ab67616d0000b273c3055e5c1073d11b1ae2e553ab67616d0000b273f30d6575306b5502236a429f',
#       'width': 60}],
#     'name': 'Top 50 Summer Electronic Songs of All Time (updated in July 2020)',
#     'owner': {'display_name': 'Red Music',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/7bntwjdswpqhrnqr0gssydbd0'},
#      'href': 'https://api.spotify.com/v1/users/7bntwjdswpqhrnqr0gssydbd0',
#      'id': '7bntwjdswpqhrnqr0gssydbd0',
#      'type': 'user',
#      'uri': 'spotify:user:7bntwjdswpqhrnqr0gssydbd0'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjQxLGVlNTE5ZWU2MmUxY2FkMTZmZjE2MWJmMGE3N2JjNDA4YTM0ZGIxYjI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0HtJC43c97s2ILhapbQHYk/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0HtJC43c97s2ILhapbQHYk'},
#    {'collaborative': False,
#     'description': 'In the next year, you will be able to find this playlist with the next title: Best Electronic Songs of All Time - Most Popular Electronic Music (Updated in 2021)',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3I7tAUuDnqBp4Tz9cfbUD7'},
#     'href': 'https://api.spotify.com/v1/playlists/3I7tAUuDnqBp4Tz9cfbUD7',
#     'id': '3I7tAUuDnqBp4Tz9cfbUD7',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731431c3bdf16aa99f71799d95ab67616d0000b273495ce6da9aeb159e94eaa453ab67616d0000b273c4d00cac55ae1b4598c9bc90ab67616d0000b273ed17a14e09145f2986a42726',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731431c3bdf16aa99f71799d95ab67616d0000b273495ce6da9aeb159e94eaa453ab67616d0000b273c4d00cac55ae1b4598c9bc90ab67616d0000b273ed17a14e09145f2986a42726',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2731431c3bdf16aa99f71799d95ab67616d0000b273495ce6da9aeb159e94eaa453ab67616d0000b273c4d00cac55ae1b4598c9bc90ab67616d0000b273ed17a14e09145f2986a42726',
#       'width': 60}],
#     'name': 'Best Electronic Songs of All Time - Most Popular Electronic Music (Updated in 2020)',
#     'owner': {'display_name': 'Red Music',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/7bntwjdswpqhrnqr0gssydbd0'},
#      'href': 'https://api.spotify.com/v1/users/7bntwjdswpqhrnqr0gssydbd0',
#      'id': '7bntwjdswpqhrnqr0gssydbd0',
#      'type': 'user',
#      'uri': 'spotify:user:7bntwjdswpqhrnqr0gssydbd0'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTk3LDYwNmI1M2U5NzFlZDlhOGU4N2NkODgxZTkxMTAzOGMyM2EwZTRiNTk=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3I7tAUuDnqBp4Tz9cfbUD7/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3I7tAUuDnqBp4Tz9cfbUD7'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1ZXD5CVT0GbP918SeTUUrI'},
#     'href': 'https://api.spotify.com/v1/playlists/1ZXD5CVT0GbP918SeTUUrI',
#     'id': '1ZXD5CVT0GbP918SeTUUrI',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27369450869a3ffaf23bc3898bfab67616d0000b273b3de5764cc02f94714487c86ab67616d0000b273c8583f0bd97d3042d4971acfab67616d0000b273ca801dab96017456b9847ac2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27369450869a3ffaf23bc3898bfab67616d0000b273b3de5764cc02f94714487c86ab67616d0000b273c8583f0bd97d3042d4971acfab67616d0000b273ca801dab96017456b9847ac2',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27369450869a3ffaf23bc3898bfab67616d0000b273b3de5764cc02f94714487c86ab67616d0000b273c8583f0bd97d3042d4971acfab67616d0000b273ca801dab96017456b9847ac2',
#       'width': 60}],
#     'name': 'Billboard Hot Dance/Electronic Songs',
#     'owner': {'display_name': 'Anson Jiang',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/22lowm2thyomlyic63iohy52a'},
#      'href': 'https://api.spotify.com/v1/users/22lowm2thyomlyic63iohy52a',
#      'id': '22lowm2thyomlyic63iohy52a',
#      'type': 'user',
#      'uri': 'spotify:user:22lowm2thyomlyic63iohy52a'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjAzLGE3NzkyYTQyNzA1NDgwZTUzZDg3ZTgzYTcwMjVmYWRkZGI0ZDU5MDc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1ZXD5CVT0GbP918SeTUUrI/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1ZXD5CVT0GbP918SeTUUrI'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/64G4ZNRbwRxTHkWAsZvOGT'},
#     'href': 'https://api.spotify.com/v1/playlists/64G4ZNRbwRxTHkWAsZvOGT',
#     'id': '64G4ZNRbwRxTHkWAsZvOGT',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732832775170b066a8239d3c55ab67616d0000b2734148e24b4baf7d370ab7a9c4ab67616d0000b2736ec290e8e94486167b8a35b6ab67616d0000b273da066328da2acd601b819b7a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732832775170b066a8239d3c55ab67616d0000b2734148e24b4baf7d370ab7a9c4ab67616d0000b2736ec290e8e94486167b8a35b6ab67616d0000b273da066328da2acd601b819b7a',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732832775170b066a8239d3c55ab67616d0000b2734148e24b4baf7d370ab7a9c4ab67616d0000b2736ec290e8e94486167b8a35b6ab67616d0000b273da066328da2acd601b819b7a',
#       'width': 60}],
#     'name': 'Electronic Songs',
#     'owner': {'display_name': 'Walter Terrell',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/gc2au5hff2sgwem7xfiawpwat'},
#      'href': 'https://api.spotify.com/v1/users/gc2au5hff2sgwem7xfiawpwat',
#      'id': 'gc2au5hff2sgwem7xfiawpwat',
#      'type': 'user',
#      'uri': 'spotify:user:gc2au5hff2sgwem7xfiawpwat'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NixkMTNlOWYzYTJhNmQyNzQwYTg1MTFiYjg3Zjk1MDQ2Y2Y0NDkwNWVj',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/64G4ZNRbwRxTHkWAsZvOGT/tracks',
#      'total': 5},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:64G4ZNRbwRxTHkWAsZvOGT'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/05iRb43PXh7AS3iEyI9vnr'},
#     'href': 'https://api.spotify.com/v1/playlists/05iRb43PXh7AS3iEyI9vnr',
#     'id': '05iRb43PXh7AS3iEyI9vnr',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273bf82130ce529153496038461ab67616d0000b273e557f9a71638189db04ed80dab67616d0000b273ef5608f271d293438fb0d4d1ab67616d0000b273f9ef39657ba18c612641ee6d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273bf82130ce529153496038461ab67616d0000b273e557f9a71638189db04ed80dab67616d0000b273ef5608f271d293438fb0d4d1ab67616d0000b273f9ef39657ba18c612641ee6d',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273bf82130ce529153496038461ab67616d0000b273e557f9a71638189db04ed80dab67616d0000b273ef5608f271d293438fb0d4d1ab67616d0000b273f9ef39657ba18c612641ee6d',
#       'width': 60}],
#     'name': 'Instrumental Electronic Songs',
#     'owner': {'display_name': 'Lucas Ruzzi',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/21h7id56n6zbhhpfap7ksga4i'},
#      'href': 'https://api.spotify.com/v1/users/21h7id56n6zbhhpfap7ksga4i',
#      'id': '21h7id56n6zbhhpfap7ksga4i',
#      'type': 'user',
#      'uri': 'spotify:user:21h7id56n6zbhhpfap7ksga4i'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTA1LDM1NjA0OTdhMzFiY2NkYWQzNzY5ZmE2YTAxOTQ3N2UxNDM3ZWRkMjA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/05iRb43PXh7AS3iEyI9vnr/tracks',
#      'total': 90},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:05iRb43PXh7AS3iEyI9vnr'},
#    {'collaborative': False,
#     'description': 'Musica electronica del año 2015',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/18ScG1ZPz4XnGlzJWksQ1K'},
#     'href': 'https://api.spotify.com/v1/playlists/18ScG1ZPz4XnGlzJWksQ1K',
#     'id': '18ScG1ZPz4XnGlzJWksQ1K',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/ab67706c0000da844e3214bf067e498ea19ea569',
#       'width': 300}],
#     'name': 'Hot Dance/Electronic Songs 2015',
#     'owner': {'display_name': 'antoniox_x',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/antoniox_x'},
#      'href': 'https://api.spotify.com/v1/users/antoniox_x',
#      'id': 'antoniox_x',
#      'type': 'user',
#      'uri': 'spotify:user:antoniox_x'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTExLGQxYjk1OWExYzY0ZGMzMjEwOTNmY2NmNWI4ODQ1MDdmNTJlNDEyYmM=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/18ScG1ZPz4XnGlzJWksQ1K/tracks',
#      'total': 98},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:18ScG1ZPz4XnGlzJWksQ1K'},
#    {'collaborative': False,
#     'description': 'Running Music Hits - Songs to run to - Run Music - Running playlist - Electronic Running - Motivation Mix - Treino',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4cgeOaRCHDkVDQPaDrRQFR'},
#     'href': 'https://api.spotify.com/v1/playlists/4cgeOaRCHDkVDQPaDrRQFR',
#     'id': '4cgeOaRCHDkVDQPaDrRQFR',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebb80d9ac85d91bad448b96c5e5',
#       'width': None}],
#     'name': 'Running Songs 2020 ',
#     'owner': {'display_name': 'LoudKult',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/43xzlwfo0tft7hn5r5e6dksrd'},
#      'href': 'https://api.spotify.com/v1/users/43xzlwfo0tft7hn5r5e6dksrd',
#      'id': '43xzlwfo0tft7hn5r5e6dksrd',
#      'type': 'user',
#      'uri': 'spotify:user:43xzlwfo0tft7hn5r5e6dksrd'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTI5NCxjYTlhODRjMjRjNzU0OWY1NTAwZWNjYWZjNTUzOGFhMWVjY2IwM2U1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4cgeOaRCHDkVDQPaDrRQFR/tracks',
#      'total': 136},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4cgeOaRCHDkVDQPaDrRQFR'},
#    {'collaborative': False,
#     'description': 'Chill Out Songs and relaxing music. 🌞Including Deep House, Chill Music, Tropical Sounds and Electronic Music 😎– Electronica, Relaxing Songs, Chill Mix, Lounge Music, Beach Music, Cafe del mar, Buddha Bar, Hotel Costes, Nikki Beach. Follow us on <a href="https://wad.lnk.to/instagram">Instagram</a>!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7ozIozDp260fjNOZy1yzRG'},
#     'href': 'https://api.spotify.com/v1/playlists/7ozIozDp260fjNOZy1yzRG',
#     'id': '7ozIozDp260fjNOZy1yzRG',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebb5306ac0ef893bec48639c2f0',
#       'width': None}],
#     'name': 'Chillout 2020',
#     'owner': {'display_name': 'We Are Diamond',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/wearediamond'},
#      'href': 'https://api.spotify.com/v1/users/wearediamond',
#      'id': 'wearediamond',
#      'type': 'user',
#      'uri': 'spotify:user:wearediamond'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjMwMSw3NDUzMmU0NmU3NDQzZGM0ODg4ODJjNjNiNzNiZmYxMDdmOTVmNDE1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7ozIozDp260fjNOZy1yzRG/tracks',
#      'total': 383},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7ozIozDp260fjNOZy1yzRG'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=electronic+songs&type=playlist&market=PH&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 2708}}

# %%
[r['name'] for r in results['playlists']['items']]
# Out:
# ["Dance Music Hits 80s 90s | Best Dance Electronic Songs of the 80's & 90's",
#  'Gym Workout Music. Hits of EDM Dance & Electronic Songs',
#  'Top 50 Summer Electronic Songs of All Time (updated in July 2020)',
#  'Best Electronic Songs of All Time - Most Popular Electronic Music (Updated in 2020)',
#  'Billboard Hot Dance/Electronic Songs',
#  'Electronic Songs',
#  'Instrumental Electronic Songs',
#  'Hot Dance/Electronic Songs 2015',
#  'Running Songs 2020 ',
#  'Chillout 2020']

# %%
[r['description'] for r in results['playlists']['items']]
# Out:
# ['Top 80s &amp; 90s Dance Songs. Classic Dance Music Hits &amp; Euro Dance from Eighties &amp; Nineties',
#  'Best Songs for Gym Workout Motivation. Electro Dance Music, Electronic Pop, Dance &amp; More Music Hits',
#  'In the next year, you will be able to find this playlist with the next title: Top 50 Summer Electronic Songs of All Time (updated in July 2021)',
#  'In the next year, you will be able to find this playlist with the next title: Best Electronic Songs of All Time - Most Popular Electronic Music (Updated in 2021)',
#  '',
#  '',
#  '',
#  'Musica electronica del año 2015',
#  'Running Music Hits - Songs to run to - Run Music - Running playlist - Electronic Running - Motivation Mix - Treino',
#  'Chill Out Songs and relaxing music. 🌞Including Deep House, Chill Music, Tropical Sounds and Electronic Music 😎– Electronica, Relaxing Songs, Chill Mix, Lounge Music, Beach Music, Cafe del mar, Buddha Bar, Hotel Costes, Nikki Beach. Follow us on <a href="https://wad.lnk.to/instagram">Instagram</a>!']

# %%
results['playlists'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['playlists']['items'][0].keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
results['playlists']['items'][0]['tracks']['total']
# Out:
# 60

# %% [markdown]
# ***

# %%
N=100
N//50
# Out:
# 2

# %%
playlist_ids = []
playlist_names = []
playlist_numtracks = []

N = 100
#get playlist in batches of 50
for n in np.arange(N//50):
    offset= 50*n
    print("Getting batch %d of search results for keyword: %s ..." % (n,KEYWORD), end='' )
    results = sp.search(q=KEYWORD, type='playlist' , market='PH', offset = offset, limit=50)
    playlist_ids.extend([p['href'].split('/')[5] for p in results['playlists']['items']])
    playlist_names.extend([p['name'] for p in results['playlists']['items']])
    playlist_numtracks.extend([p['tracks']['total'] for p in results['playlists']['items']])
    print("  DONE!")
# Out:
# Getting batch 0 of search results for keyword: electronic songs ...  DONE!
# Getting batch 1 of search results for keyword: electronic songs ...  DONE!

# %%
playlist_names
# Out:
# ["Dance Music Hits 80s 90s | Best Dance Electronic Songs of the 80's & 90's",
#  'Top 100 Most Popular Electronic Songs of all Time',
#  'Gym Workout Music. Hits of EDM Dance & Electronic Songs',
#  'Best Electronic Songs of All Time - Most Popular Electronic Music (Updated in 2020)',
#  'Top 50 Summer Electronic Songs of All Time (updated in July 2020)',
#  'Billboard Hot Dance/Electronic Songs',
#  'Electronic Songs',
#  'Instrumental Electronic Songs',
#  'Hot Dance/Electronic Songs 2015',
#  'Running Songs 2020 ',
#  'Chillout 2020',
#  "BPM - Today's Dance Hits",
#  'EDM Remixes of Popular Songs',
#  'Sex Songs 🔞🔥 : Alt Pop / Dark Pop / Electronic / Bedroom Jam / Sexy Vibes ',
#  'Electronic: Study No Words',
#  'La Mejor Música Electrónica Pop, Trap | Tomorrowland 2020 | 3L3CTRONICA',
#  '👑 Best Remixes of Popular Songs 2020 👑',
#  'Future Bass Hits ⚡ Electrónica 2020 ⚡ Chill Music 2020',
#  'The Climb 170-175 BPM',
#  'Chill Electronic Music 2019',
#  'Newest Electronic / House Songs 2020',
#  'Secret Electronica',
#  'Summer 2020 🌴🍹 EDM Hits and Electronica',
#  "Wave Music's Favorites - Chill Electronic & Pop Music",
#  'Chillout',
#  'Gaming Playlist 🎮 | EDM - BASS - TRAP | 🕹️ Gaming Music',
#  'Melodic Electronic Music 2019',
#  'ELECTRIC NOSTALGIA || Indie-Electronic Anthems',
#  'Exitós Electronicas 2020 🚀 EDM ',
#  'Christian Electronic Worship Remixes',
#  'Musica Electronica 2010 a 2019',
#  'Top Hits 2020',
#  'Sad electronic',
#  'House Music 2020',
#  'Bangers',
#  'GAMING MUSIC 2020 | COD MODERN WARFARE',
#  'LOVE TRAP | BEDROOM POP 2020',
#  'Oldies Remixed ( Oldies Remixes) Remixes of Old Songs & Oldies Electronic 2000s 90s 80s 70s 60s',
#  'Trailer Music / Cinematic Songs / Orchestral / Electronic / Dark / Epic Music / Cinematic Pop',
#  'Electronic/ House music',
#  'Latin EDM - Latin House 2020 ( Latin Electronica - La Mejor Musica Electronica 2020 )',
#  'Fresh Squeezed Art',
#  'Electric Drive',
#  'Chillout & Electronic 2020',
#  'Happy Summer Mix 2020',
#  "Jake's Electronic Playlist",
#  'Electro Vibes',
#  'Battlefield Vietnam (Soundtrack)',
#  'Miracle Of Sound Songs',
#  'Gaming Music – Electronic Gaming Songs',
#  'Best Dj Songs English 2020 to 2021 ♫ Electronic Party Music 2020 to 2021',
#  'Cover Songs 2020 | Pop Rock Music Covers',
#  'Metalcore / Hardcore / Post Hardcore / Screamo / Electronic Hardcore / Postcore / 4000 + Songs',
#  'Syrex Favourites | EDM - Electronic - Pop - Trap | New Music Friday',
#  'Coffee Beats & Electronic Waves ',
#  'Coding Playlist | (almost) No Vocals',
#  'Clean EDM Workout 2020 (Clean EDM Songs 2020) Electronic Workout 2020',
#  'Dancing Alien',
#  'No Lyrics - Electronic',
#  'top running songs. // Fun Run 150–165 BPM // Run This Town 150–165 BPM',
#  'We Are Diamond',
#  'East Los FM - GTA V',
#  'Thievery Corporation Essentials',
#  'Top 50 EDM Songs of the Decade',
#  'The Best Electronic/Dance Running Songs',
#  'Melodic Electronic Music 2020',
#  'The best driving songs (mix rock n electronic)',
#  'We are BUNT.',
#  'UK Garage / UKG',
#  'CAR BASS ⚡ BASS BOOSTED 🔥 CAR MUSIC REMIXES',
#  'Bass test: Songs for Headphones & Subwoofers',
#  'Jean-Michel Jarre Essential Hits',
#  'Ultimate HIIT Workout 2020',
#  'Ibiza Mix 2019',
#  'Albert Vishi Playlist',
#  'VERBOTEN BERLIN - Electronic Night Kitsch',
#  'Chill 2020 - Relaxing New Dance & Pop Music (Chill Music Playlist)',
#  'Festa Rave 2020 - Alok Astrix Berg Blastoyz Hi Profile Ranji Skazi Vegas Vini Vici Mandragora',
#  'EDM Workout & Cardio 👟',
#  'Chillout 2020',
#  'The Guardian: soothing songs to self-isolate with',
#  'Upbeat Electronica',
#  'LEAGUE RECAP',
#  'FOLK HOUSE by BUNT.',
#  'EDM Tiktok Songs: Tiktok Dance Songs (Electronic Tiktok Sogs 2020) Tik Tok EDM Songs 2020',
#  'Deep House / Tech House',
#  'Female Vocal Electronica - Vocal EDM Songs',
#  'Christian Dance Party',
#  'EDM Top 40',
#  'Dark Space | Ambient Electronic | IDM | Electro | EDM | Krautrock | Soundtrack | Synth',
#  'Instrumental Electronic Hits',
#  "Modern 80's Covers",
#  'Sad Songs for Sad Goths',
#  'Chill Out Songs 🌴',
#  'focus beats & lofi study : electronic study music 2019 - chill electronic hip hop vibes',
#  'Beach Lounge 2020 & Chillout Lounge 🌴 Ibiza Sunset- Chill Electronic Pop Music - Chill Summer Music',
#  'EDM Club Mixes',
#  'Cardio Playlist',
#  'Top 50 EDM Songs of 2013 & 2012',
#  'Club Electro - Dance - GYM Music - Summer Sounds 2020']

# %% [markdown]
# ## 2. Get Playlist Data

# %% [markdown]
# ##### View the structure of a playlist query

# %%
playlist = sp.playlist('37i9dQZF1DX4olOMiqFeqU')

# %%
playlist
# Out:
# {'collaborative': False,
#  'description': '100% Pinoy hits from your favorite artists!',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4olOMiqFeqU'},
#  'followers': {'href': None, 'total': 1991844},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4olOMiqFeqU?additional_types=track',
#  'id': '37i9dQZF1DX4olOMiqFeqU',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000003686604cfc2467f94dfcd8e3a',
#    'width': None}],
#  'name': 'OPM Favorites',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'MTYwMjU5MTA0OSwwMDAwMDAwMGYyZGQ1NmM3ZGJiZGQ5MmQ5MTI5ZTg4MWYyMWIzNWY1',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4olOMiqFeqU/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7374lH6kwx9uQATYQ9H3Cp'},
#         'href': 'https://api.spotify.com/v1/artists/7374lH6kwx9uQATYQ9H3Cp',
#         'id': '7374lH6kwx9uQATYQ9H3Cp',
#         'name': 'Eraserheads',
#         'type': 'artist',
#         'uri': 'spotify:artist:7374lH6kwx9uQATYQ9H3Cp'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2DIpgoeZAbwk3wF1qSDj8v'},
#       'href': 'https://api.spotify.com/v1/albums/2DIpgoeZAbwk3wF1qSDj8v',
#       'id': '2DIpgoeZAbwk3wF1qSDj8v',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27383a474e86be1eebb17df6726',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0283a474e86be1eebb17df6726',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485183a474e86be1eebb17df6726',
#         'width': 64}],
#       'name': 'Anthology',
#       'release_date': '2004-01-23',
#       'release_date_precision': 'day',
#       'total_tracks': 33,
#       'type': 'album',
#       'uri': 'spotify:album:2DIpgoeZAbwk3wF1qSDj8v'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7374lH6kwx9uQATYQ9H3Cp'},
#        'href': 'https://api.spotify.com/v1/artists/7374lH6kwx9uQATYQ9H3Cp',
#        'id': '7374lH6kwx9uQATYQ9H3Cp',
#        'name': 'Eraserheads',
#        'type': 'artist',
#        'uri': 'spotify:artist:7374lH6kwx9uQATYQ9H3Cp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 271466,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHBO10100222'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6SHSvo6OGgpneKfsxFGhhk'},
#      'href': 'https://api.spotify.com/v1/tracks/6SHSvo6OGgpneKfsxFGhhk',
#      'id': '6SHSvo6OGgpneKfsxFGhhk',
#      'is_local': False,
#      'name': 'Ligaya',
#      'popularity': 55,
#      'preview_url': 'https://p.scdn.co/mp3-preview/fca7a630556bff734e9f56a3efd8e0c3a1c6c2cb?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6SHSvo6OGgpneKfsxFGhhk'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#         'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#         'id': '6aiCKnIN68hohzU3ZzNq48',
#         'name': 'Sarah Geronimo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/42F8uTX1DR3OiaKVtrz3Gr'},
#       'href': 'https://api.spotify.com/v1/albums/42F8uTX1DR3OiaKVtrz3Gr',
#       'id': '42F8uTX1DR3OiaKVtrz3Gr',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732a8ce1962ab70fd8b7d062c2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022a8ce1962ab70fd8b7d062c2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512a8ce1962ab70fd8b7d062c2',
#         'width': 64}],
#       'name': 'The Great Unknown',
#       'release_date': '2015-12-04',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:42F8uTX1DR3OiaKVtrz3Gr'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#        'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#        'id': '6aiCKnIN68hohzU3ZzNq48',
#        'name': 'Sarah Geronimo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 245053,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHV031510085'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4T7CM071eEoHudiDShZlCJ'},
#      'href': 'https://api.spotify.com/v1/tracks/4T7CM071eEoHudiDShZlCJ',
#      'id': '4T7CM071eEoHudiDShZlCJ',
#      'is_local': False,
#      'name': 'Tala',
#      'popularity': 63,
#      'preview_url': 'https://p.scdn.co/mp3-preview/9e7b3a5bf3240651896e045107338ea6a3bd66f6?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 9,
#      'type': 'track',
#      'uri': 'spotify:track:4T7CM071eEoHudiDShZlCJ'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HIZU0JzM0AgfItVOm4E08'},
#         'href': 'https://api.spotify.com/v1/artists/5HIZU0JzM0AgfItVOm4E08',
#         'id': '5HIZU0JzM0AgfItVOm4E08',
#         'name': 'This Band',
#         'type': 'artist',
#         'uri': 'spotify:artist:5HIZU0JzM0AgfItVOm4E08'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2sGiNJNhNMJbn56l0BE0R0'},
#       'href': 'https://api.spotify.com/v1/albums/2sGiNJNhNMJbn56l0BE0R0',
#       'id': '2sGiNJNhNMJbn56l0BE0R0',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273229f723cc430e9d2d8a5920a',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02229f723cc430e9d2d8a5920a',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851229f723cc430e9d2d8a5920a',
#         'width': 64}],
#       'name': 'Kahit Ayaw Mo Na',
#       'release_date': '2018-11-02',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:2sGiNJNhNMJbn56l0BE0R0'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HIZU0JzM0AgfItVOm4E08'},
#        'href': 'https://api.spotify.com/v1/artists/5HIZU0JzM0AgfItVOm4E08',
#        'id': '5HIZU0JzM0AgfItVOm4E08',
#        'name': 'This Band',
#        'type': 'artist',
#        'uri': 'spotify:artist:5HIZU0JzM0AgfItVOm4E08'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 243015,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USCGH1864517'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/58grXgbCj7t5ulr0TGLIr9'},
#      'href': 'https://api.spotify.com/v1/tracks/58grXgbCj7t5ulr0TGLIr9',
#      'id': '58grXgbCj7t5ulr0TGLIr9',
#      'is_local': False,
#      'name': 'Kahit Ayaw Mo Na',
#      'popularity': 65,
#      'preview_url': 'https://p.scdn.co/mp3-preview/1dbe606aa34cd8fa75caedd742dc2310728226f7?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:58grXgbCj7t5ulr0TGLIr9'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qFxP3qN9GsnZDOkAE6x2m'},
#         'href': 'https://api.spotify.com/v1/artists/4qFxP3qN9GsnZDOkAE6x2m',
#         'id': '4qFxP3qN9GsnZDOkAE6x2m',
#         'name': 'December Avenue',
#         'type': 'artist',
#         'uri': 'spotify:artist:4qFxP3qN9GsnZDOkAE6x2m'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7xconhHQKj7Be4P2KvUmFz'},
#       'href': 'https://api.spotify.com/v1/albums/7xconhHQKj7Be4P2KvUmFz',
#       'id': '7xconhHQKj7Be4P2KvUmFz',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273266d80116545e01826910bbd',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02266d80116545e01826910bbd',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851266d80116545e01826910bbd',
#         'width': 64}],
#       'name': 'Sa Ngalan Ng Pag-Ibig',
#       'release_date': '2017-04-29',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:7xconhHQKj7Be4P2KvUmFz'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qFxP3qN9GsnZDOkAE6x2m'},
#        'href': 'https://api.spotify.com/v1/artists/4qFxP3qN9GsnZDOkAE6x2m',
#        'id': '4qFxP3qN9GsnZDOkAE6x2m',
#        'name': 'December Avenue',
#        'type': 'artist',
#        'uri': 'spotify:artist:4qFxP3qN9GsnZDOkAE6x2m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 285138,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMPKX1753025'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/00mBzIWv5gHOYxwuEJXjOG'},
#      'href': 'https://api.spotify.com/v1/tracks/00mBzIWv5gHOYxwuEJXjOG',
#      'id': '00mBzIWv5gHOYxwuEJXjOG',
#      'is_local': False,
#      'name': 'Sa Ngalan Ng Pag-Ibig',
#      'popularity': 66,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4626adec259ce7f45bf99b287a1f263fa38e5dd1?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:00mBzIWv5gHOYxwuEJXjOG'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28B54RKpJrEmDoGSTjsfY6'},
#         'href': 'https://api.spotify.com/v1/artists/28B54RKpJrEmDoGSTjsfY6',
#         'id': '28B54RKpJrEmDoGSTjsfY6',
#         'name': 'Magnus Haven',
#         'type': 'artist',
#         'uri': 'spotify:artist:28B54RKpJrEmDoGSTjsfY6'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/04KG42EaTfjaPbYHQ6wI3h'},
#       'href': 'https://api.spotify.com/v1/albums/04KG42EaTfjaPbYHQ6wI3h',
#       'id': '04KG42EaTfjaPbYHQ6wI3h',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732e9ea57a8a6a9607f7048b67',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022e9ea57a8a6a9607f7048b67',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512e9ea57a8a6a9607f7048b67',
#         'width': 64}],
#       'name': 'Imahe',
#       'release_date': '2018-11-30',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:04KG42EaTfjaPbYHQ6wI3h'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28B54RKpJrEmDoGSTjsfY6'},
#        'href': 'https://api.spotify.com/v1/artists/28B54RKpJrEmDoGSTjsfY6',
#        'id': '28B54RKpJrEmDoGSTjsfY6',
#        'name': 'Magnus Haven',
#        'type': 'artist',
#        'uri': 'spotify:artist:28B54RKpJrEmDoGSTjsfY6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 321817,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHW011800811'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/65sEZZaxTjLMD8vNgPoMz5'},
#      'href': 'https://api.spotify.com/v1/tracks/65sEZZaxTjLMD8vNgPoMz5',
#      'id': '65sEZZaxTjLMD8vNgPoMz5',
#      'is_local': False,
#      'name': 'Imahe',
#      'popularity': 72,
#      'preview_url': 'https://p.scdn.co/mp3-preview/3cc243dbbad2e69f14d798ecb813bf7e04efb32e?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:65sEZZaxTjLMD8vNgPoMz5'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BNWanhw4AjSXjBm9L1Jzy'},
#         'href': 'https://api.spotify.com/v1/artists/4BNWanhw4AjSXjBm9L1Jzy',
#         'id': '4BNWanhw4AjSXjBm9L1Jzy',
#         'name': 'Juris',
#         'type': 'artist',
#         'uri': 'spotify:artist:4BNWanhw4AjSXjBm9L1Jzy'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7nEylzolYuExnVXy0TCPie'},
#       'href': 'https://api.spotify.com/v1/albums/7nEylzolYuExnVXy0TCPie',
#       'id': '7nEylzolYuExnVXy0TCPie',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734b1aa56e662e44b9dbd1ddcb',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024b1aa56e662e44b9dbd1ddcb',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514b1aa56e662e44b9dbd1ddcb',
#         'width': 64}],
#       'name': 'Forevermore',
#       'release_date': '2012-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7nEylzolYuExnVXy0TCPie'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BNWanhw4AjSXjBm9L1Jzy'},
#        'href': 'https://api.spotify.com/v1/artists/4BNWanhw4AjSXjBm9L1Jzy',
#        'id': '4BNWanhw4AjSXjBm9L1Jzy',
#        'name': 'Juris',
#        'type': 'artist',
#        'uri': 'spotify:artist:4BNWanhw4AjSXjBm9L1Jzy'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 294716,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHS091104168'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3U7TJUjNz7pgPSfgeGQjsP'},
#      'href': 'https://api.spotify.com/v1/tracks/3U7TJUjNz7pgPSfgeGQjsP',
#      'id': '3U7TJUjNz7pgPSfgeGQjsP',
#      'is_local': False,
#      'name': 'Forevermore',
#      'popularity': 59,
#      'preview_url': 'https://p.scdn.co/mp3-preview/43999982ee26ace4a48a993568ed062b04145746?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:3U7TJUjNz7pgPSfgeGQjsP'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#         'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#         'id': '0rZRTXEmmPmx6gt92tBqIc',
#         'name': 'Moira Dela Torre',
#         'type': 'artist',
#         'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/52xu8EP3ABmpNk0LUzF3ih'},
#       'href': 'https://api.spotify.com/v1/albums/52xu8EP3ABmpNk0LUzF3ih',
#       'id': '52xu8EP3ABmpNk0LUzF3ih',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273b6a618ab41335201afc16b81',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02b6a618ab41335201afc16b81',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851b6a618ab41335201afc16b81',
#         'width': 64}],
#       'name': 'Malaya (Camp Sawi Original Motion Picture Soundtrack)',
#       'release_date': '2017-09-18',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:52xu8EP3ABmpNk0LUzF3ih'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#        'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#        'id': '0rZRTXEmmPmx6gt92tBqIc',
#        'name': 'Moira Dela Torre',
#        'type': 'artist',
#        'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 254249,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GB-SMU-29-78835'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6M21eWbEw74XDdoQsNIinq'},
#      'href': 'https://api.spotify.com/v1/tracks/6M21eWbEw74XDdoQsNIinq',
#      'id': '6M21eWbEw74XDdoQsNIinq',
#      'is_local': False,
#      'name': 'Malaya (Camp Sawi Original Motion Picture Soundtrack)',
#      'popularity': 59,
#      'preview_url': 'https://p.scdn.co/mp3-preview/278202994437dd2ec90fbed0c08b5317eff4ad21?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6M21eWbEw74XDdoQsNIinq'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nGp682WMiKS4X217kPw8C'},
#         'href': 'https://api.spotify.com/v1/artists/4nGp682WMiKS4X217kPw8C',
#         'id': '4nGp682WMiKS4X217kPw8C',
#         'name': 'Silent Sanctuary',
#         'type': 'artist',
#         'uri': 'spotify:artist:4nGp682WMiKS4X217kPw8C'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/38jqi8VvSax4miNL2cacD1'},
#       'href': 'https://api.spotify.com/v1/albums/38jqi8VvSax4miNL2cacD1',
#       'id': '38jqi8VvSax4miNL2cacD1',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27324e40ba8327d578c9413ce36',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0224e40ba8327d578c9413ce36',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485124e40ba8327d578c9413ce36',
#         'width': 64}],
#       'name': 'Langit. Luha.',
#       'release_date': '2015-04-08',
#       'release_date_precision': 'day',
#       'total_tracks': 8,
#       'type': 'album',
#       'uri': 'spotify:album:38jqi8VvSax4miNL2cacD1'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nGp682WMiKS4X217kPw8C'},
#        'href': 'https://api.spotify.com/v1/artists/4nGp682WMiKS4X217kPw8C',
#        'id': '4nGp682WMiKS4X217kPw8C',
#        'name': 'Silent Sanctuary',
#        'type': 'artist',
#        'uri': 'spotify:artist:4nGp682WMiKS4X217kPw8C'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 241029,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHI011405630'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0YyM8aEdbjGfLWPn6fdcn7'},
#      'href': 'https://api.spotify.com/v1/tracks/0YyM8aEdbjGfLWPn6fdcn7',
#      'id': '0YyM8aEdbjGfLWPn6fdcn7',
#      'is_local': False,
#      'name': 'Pasensya Ka Na',
#      'popularity': 62,
#      'preview_url': 'https://p.scdn.co/mp3-preview/671a52310fa06ef356df56c51b6826560ce90765?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:0YyM8aEdbjGfLWPn6fdcn7'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Is0yeBka3hK5PSob7HTLs'},
#       'href': 'https://api.spotify.com/v1/albums/2Is0yeBka3hK5PSob7HTLs',
#       'id': '2Is0yeBka3hK5PSob7HTLs',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273d56bb7a4d884f0f02cac382b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02d56bb7a4d884f0f02cac382b',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851d56bb7a4d884f0f02cac382b',
#         'width': 64}],
#       'name': 'Vince & Kath & James (Original Motion Picture Soundtrack)',
#       'release_date': '2016-12-16',
#       'release_date_precision': 'day',
#       'total_tracks': 8,
#       'type': 'album',
#       'uri': 'spotify:album:2Is0yeBka3hK5PSob7HTLs'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qnQOnL1oLKtH779qZ6iuR'},
#        'href': 'https://api.spotify.com/v1/artists/2qnQOnL1oLKtH779qZ6iuR',
#        'id': '2qnQOnL1oLKtH779qZ6iuR',
#        'name': 'Ylona Garcia',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qnQOnL1oLKtH779qZ6iuR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/69ug07KFFRhcCZ7iZ1Mn1i'},
#        'href': 'https://api.spotify.com/v1/artists/69ug07KFFRhcCZ7iZ1Mn1i',
#        'id': '69ug07KFFRhcCZ7iZ1Mn1i',
#        'name': 'Bailey May',
#        'type': 'artist',
#        'uri': 'spotify:artist:69ug07KFFRhcCZ7iZ1Mn1i'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 217453,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHS091605475'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6bLMHyeVCs2ki3nPUEhAjR'},
#      'href': 'https://api.spotify.com/v1/tracks/6bLMHyeVCs2ki3nPUEhAjR',
#      'id': '6bLMHyeVCs2ki3nPUEhAjR',
#      'is_local': False,
#      'name': 'O Pag-Ibig',
#      'popularity': 35,
#      'preview_url': 'https://p.scdn.co/mp3-preview/a832f1e678489f5aae527776481d40e5962ef39c?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:6bLMHyeVCs2ki3nPUEhAjR'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#         'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#         'id': '6aiCKnIN68hohzU3ZzNq48',
#         'name': 'Sarah Geronimo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0BGReR0ClYIme8zAabt53h'},
#       'href': 'https://api.spotify.com/v1/albums/0BGReR0ClYIme8zAabt53h',
#       'id': '0BGReR0ClYIme8zAabt53h',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27354977fc898459edc2b4a325c',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0254977fc898459edc2b4a325c',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485154977fc898459edc2b4a325c',
#         'width': 64}],
#       'name': 'Maybe This Time (From "Maybe This Time")',
#       'release_date': '2016-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
# ...
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nZa8vRD64ueq3d0JNYTsl'},
#         'href': 'https://api.spotify.com/v1/artists/3nZa8vRD64ueq3d0JNYTsl',
#         'id': '3nZa8vRD64ueq3d0JNYTsl',
#         'name': '6cyclemind',
#         'type': 'artist',
#         'uri': 'spotify:artist:3nZa8vRD64ueq3d0JNYTsl'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1Im5BTDBghgM0NG75SaiC3'},
#       'href': 'https://api.spotify.com/v1/albums/1Im5BTDBghgM0NG75SaiC3',
#       'id': '1Im5BTDBghgM0NG75SaiC3',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273efe819c5d4a3cc6c59831852',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02efe819c5d4a3cc6c59831852',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851efe819c5d4a3cc6c59831852',
#         'width': 64}],
#       'name': 'Home',
#       'release_date': '2007-01-15',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:1Im5BTDBghgM0NG75SaiC3'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nZa8vRD64ueq3d0JNYTsl'},
#        'href': 'https://api.spotify.com/v1/artists/3nZa8vRD64ueq3d0JNYTsl',
#        'id': '3nZa8vRD64ueq3d0JNYTsl',
#        'name': '6cyclemind',
#        'type': 'artist',
#        'uri': 'spotify:artist:3nZa8vRD64ueq3d0JNYTsl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 267293,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHBO10700836'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2S80c51YXgJQhkhX603fMA'},
#      'href': 'https://api.spotify.com/v1/tracks/2S80c51YXgJQhkhX603fMA',
#      'id': '2S80c51YXgJQhkhX603fMA',
#      'is_local': False,
#      'name': 'Prinsesa',
#      'popularity': 57,
#      'preview_url': 'https://p.scdn.co/mp3-preview/73dd68cc9e3a170dcba6457cbb470b16c7832f30?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:2S80c51YXgJQhkhX603fMA'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/33qqYIFSFSVYO3wCkc1Ksh'},
#       'href': 'https://api.spotify.com/v1/albums/33qqYIFSFSVYO3wCkc1Ksh',
#       'id': '33qqYIFSFSVYO3wCkc1Ksh',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273e79447782758701854a62cef',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02e79447782758701854a62cef',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851e79447782758701854a62cef',
#         'width': 64}],
#       'name': 'Pauwi Nako',
#       'release_date': '2018-07-28',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:33qqYIFSFSVYO3wCkc1Ksh'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iqkVK6sTXi7DZWWOeKy8Q'},
#        'href': 'https://api.spotify.com/v1/artists/0iqkVK6sTXi7DZWWOeKy8Q',
#        'id': '0iqkVK6sTXi7DZWWOeKy8Q',
#        'name': 'PDL',
#        'type': 'artist',
#        'uri': 'spotify:artist:0iqkVK6sTXi7DZWWOeKy8Q'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/117XFtbZPnCI1EYKjYZWJc'},
#        'href': 'https://api.spotify.com/v1/artists/117XFtbZPnCI1EYKjYZWJc',
#        'id': '117XFtbZPnCI1EYKjYZWJc',
#        'name': 'Skusta Clee',
#        'type': 'artist',
#        'uri': 'spotify:artist:117XFtbZPnCI1EYKjYZWJc'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0uD1WQbTE0pNDiJe0iGEaU'},
#        'href': 'https://api.spotify.com/v1/artists/0uD1WQbTE0pNDiJe0iGEaU',
#        'id': '0uD1WQbTE0pNDiJe0iGEaU',
#        'name': 'Jnske',
#        'type': 'artist',
#        'uri': 'spotify:artist:0uD1WQbTE0pNDiJe0iGEaU'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5MfvrLwRcs98YwS3C9Uf1u'},
#        'href': 'https://api.spotify.com/v1/artists/5MfvrLwRcs98YwS3C9Uf1u',
#        'id': '5MfvrLwRcs98YwS3C9Uf1u',
#        'name': 'Bullet D',
#        'type': 'artist',
#        'uri': 'spotify:artist:5MfvrLwRcs98YwS3C9Uf1u'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xOvrnVpLjzfGi69GDlzQY'},
#        'href': 'https://api.spotify.com/v1/artists/5xOvrnVpLjzfGi69GDlzQY',
#        'id': '5xOvrnVpLjzfGi69GDlzQY',
#        'name': 'Yuridope',
#        'type': 'artist',
#        'uri': 'spotify:artist:5xOvrnVpLjzfGi69GDlzQY'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3PDFGpPl4ienSn5Vwisfrh'},
#        'href': 'https://api.spotify.com/v1/artists/3PDFGpPl4ienSn5Vwisfrh',
#        'id': '3PDFGpPl4ienSn5Vwisfrh',
#        'name': 'Flow G',
#        'type': 'artist',
#        'uri': 'spotify:artist:3PDFGpPl4ienSn5Vwisfrh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 341573,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'TCADT1835182'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2tzAN1L07SNwnOdgOEeuQr'},
#      'href': 'https://api.spotify.com/v1/tracks/2tzAN1L07SNwnOdgOEeuQr',
#      'id': '2tzAN1L07SNwnOdgOEeuQr',
#      'is_local': False,
#      'name': 'Pauwi Nako',
#      'popularity': 63,
#      'preview_url': 'https://p.scdn.co/mp3-preview/26122cea968dfa29f6270901cbab215158b01a2b?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2tzAN1L07SNwnOdgOEeuQr'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2020-10-05T08:50:05Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#         'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#         'id': '0rZRTXEmmPmx6gt92tBqIc',
#         'name': 'Moira Dela Torre',
#         'type': 'artist',
#         'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'KZ',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VN',
#        'XK',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/05rQadwAVYTpNNnBoeTuj0'},
#       'href': 'https://api.spotify.com/v1/albums/05rQadwAVYTpNNnBoeTuj0',
#       'id': '05rQadwAVYTpNNnBoeTuj0',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27384c39a72230ca78d8223dcec',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0284c39a72230ca78d8223dcec',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485184c39a72230ca78d8223dcec',
#         'width': 64}],
#       'name': 'Malaya',
#       'release_date': '2018-02-19',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:05rQadwAVYTpNNnBoeTuj0'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#        'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#        'id': '0rZRTXEmmPmx6gt92tBqIc',
#        'name': 'Moira Dela Torre',
#        'type': 'artist',
#        'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 320320,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'PHS031700772'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/70bc7AZ8MN5niphOXyHpsD'},
#      'href': 'https://api.spotify.com/v1/tracks/70bc7AZ8MN5niphOXyHpsD',
#      'id': '70bc7AZ8MN5niphOXyHpsD',
#      'is_local': False,
#      'name': 'Malaya',
#      'popularity': 55,
#      'preview_url': 'https://p.scdn.co/mp3-preview/fe7a31b266d4b9f2487b4e38cf133db05ef0480e?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:70bc7AZ8MN5niphOXyHpsD'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 50},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:37i9dQZF1DX4olOMiqFeqU'}

# %%
playlist.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %% [markdown]
# ***

# %%
playlist_lookup = []
for n,p_id in enumerate(playlist_ids):
    print("Getting playlist data for playlist %s :..." % (playlist_names[n]), end='' )
    playlist = sp.playlist(p_id)
    try:
        relevant_playlist_data = { key: playlist[key] for key in ['followers','owner']}
        relevant_playlist_data['playlist_id'] = p_id
        relevant_playlist_data['playlist_name'] = playlist_names[n]
        relevant_playlist_data['playlist_total_tracks'] = playlist_numtracks[n]
        relevant_playlist_data['owner_id'] = playlist['owner']['id']
        relevant_playlist_data['owner_name'] = playlist['owner']['display_name']
        relevant_playlist_data['total_followers'] = playlist['followers']['total']
        relevant_playlist_data.pop('owner', None)
        relevant_playlist_data.pop('followers', None)
        playlist_lookup.append(relevant_playlist_data)
        print("   DONE")
    except:
        print("   Aborted")
        continue
# Out:
# Getting playlist data for playlist Dance Music Hits 80s 90s | Best Dance Electronic Songs of the 80's & 90's :...   DONE
# Getting playlist data for playlist Top 100 Most Popular Electronic Songs of all Time :...   DONE
# Getting playlist data for playlist Gym Workout Music. Hits of EDM Dance & Electronic Songs :...   DONE
# Getting playlist data for playlist Best Electronic Songs of All Time - Most Popular Electronic Music (Updated in 2020) :...   DONE
# Getting playlist data for playlist Top 50 Summer Electronic Songs of All Time (updated in July 2020) :...   DONE
# Getting playlist data for playlist Billboard Hot Dance/Electronic Songs :...   DONE
# Getting playlist data for playlist Electronic Songs :...   DONE
# Getting playlist data for playlist Instrumental Electronic Songs :...   DONE
# Getting playlist data for playlist Hot Dance/Electronic Songs 2015 :...   DONE
# Getting playlist data for playlist Running Songs 2020  :...   DONE
# Getting playlist data for playlist Chillout 2020 :...   DONE
# Getting playlist data for playlist BPM - Today's Dance Hits :...   DONE
# Getting playlist data for playlist EDM Remixes of Popular Songs :...   DONE
# Getting playlist data for playlist Sex Songs 🔞🔥 : Alt Pop / Dark Pop / Electronic / Bedroom Jam / Sexy Vibes  :...   DONE
# Getting playlist data for playlist Electronic: Study No Words :...   DONE
# Getting playlist data for playlist La Mejor Música Electrónica Pop, Trap | Tomorrowland 2020 | 3L3CTRONICA :...   DONE
# Getting playlist data for playlist 👑 Best Remixes of Popular Songs 2020 👑 :...   DONE
# Getting playlist data for playlist Future Bass Hits ⚡ Electrónica 2020 ⚡ Chill Music 2020 :...   DONE
# Getting playlist data for playlist The Climb 170-175 BPM :...   DONE
# Getting playlist data for playlist Chill Electronic Music 2019 :...   DONE
# Getting playlist data for playlist Newest Electronic / House Songs 2020 :...   DONE
# Getting playlist data for playlist Secret Electronica :...   DONE
# Getting playlist data for playlist Summer 2020 🌴🍹 EDM Hits and Electronica :...   DONE
# Getting playlist data for playlist Wave Music's Favorites - Chill Electronic & Pop Music :...   DONE
# Getting playlist data for playlist Chillout :...   DONE
# Getting playlist data for playlist Gaming Playlist 🎮 | EDM - BASS - TRAP | 🕹️ Gaming Music :...   DONE
# Getting playlist data for playlist Melodic Electronic Music 2019 :...   DONE
# Getting playlist data for playlist ELECTRIC NOSTALGIA || Indie-Electronic Anthems :...   DONE
# Getting playlist data for playlist Exitós Electronicas 2020 🚀 EDM  :...   DONE
# Getting playlist data for playlist Christian Electronic Worship Remixes :...   DONE
# Getting playlist data for playlist Musica Electronica 2010 a 2019 :...   DONE
# Getting playlist data for playlist Top Hits 2020 :...   DONE
# Getting playlist data for playlist Sad electronic :...   DONE
# Getting playlist data for playlist House Music 2020 :...   DONE
# Getting playlist data for playlist Bangers :...   DONE
# Getting playlist data for playlist GAMING MUSIC 2020 | COD MODERN WARFARE :...   DONE
# Getting playlist data for playlist LOVE TRAP | BEDROOM POP 2020 :...   DONE
# Getting playlist data for playlist Oldies Remixed ( Oldies Remixes) Remixes of Old Songs & Oldies Electronic 2000s 90s 80s 70s 60s :...   DONE
# Getting playlist data for playlist Trailer Music / Cinematic Songs / Orchestral / Electronic / Dark / Epic Music / Cinematic Pop :...   DONE
# Getting playlist data for playlist Electronic/ House music :...   DONE
# Getting playlist data for playlist Latin EDM - Latin House 2020 ( Latin Electronica - La Mejor Musica Electronica 2020 ) :...   DONE
# Getting playlist data for playlist Fresh Squeezed Art :...   DONE
# Getting playlist data for playlist Electric Drive :...   DONE
# Getting playlist data for playlist Chillout & Electronic 2020 :...   DONE
# Getting playlist data for playlist Happy Summer Mix 2020 :...   DONE
# Getting playlist data for playlist Jake's Electronic Playlist :...   DONE
# Getting playlist data for playlist Electro Vibes :...   DONE
# Getting playlist data for playlist Battlefield Vietnam (Soundtrack) :...   DONE
# Getting playlist data for playlist Miracle Of Sound Songs :...   DONE
# Getting playlist data for playlist Gaming Music – Electronic Gaming Songs :...   DONE
# Getting playlist data for playlist Best Dj Songs English 2020 to 2021 ♫ Electronic Party Music 2020 to 2021 :...   DONE
# Getting playlist data for playlist Cover Songs 2020 | Pop Rock Music Covers :...   DONE
# Getting playlist data for playlist Metalcore / Hardcore / Post Hardcore / Screamo / Electronic Hardcore / Postcore / 4000 + Songs :...   DONE
# Getting playlist data for playlist Syrex Favourites | EDM - Electronic - Pop - Trap | New Music Friday :...   DONE
# Getting playlist data for playlist Coffee Beats & Electronic Waves  :...   DONE
# Getting playlist data for playlist Coding Playlist | (almost) No Vocals :...   DONE
# Getting playlist data for playlist Clean EDM Workout 2020 (Clean EDM Songs 2020) Electronic Workout 2020 :...   DONE
# Getting playlist data for playlist Dancing Alien :...   DONE
# Getting playlist data for playlist No Lyrics - Electronic :...   DONE
# Getting playlist data for playlist top running songs. // Fun Run 150–165 BPM // Run This Town 150–165 BPM :...   DONE
# Getting playlist data for playlist We Are Diamond :...   DONE
# Getting playlist data for playlist East Los FM - GTA V :...   DONE
# Getting playlist data for playlist Thievery Corporation Essentials :...   DONE
# Getting playlist data for playlist Top 50 EDM Songs of the Decade :...   DONE
# Getting playlist data for playlist The Best Electronic/Dance Running Songs :...   DONE
# Getting playlist data for playlist Melodic Electronic Music 2020 :...   DONE
# Getting playlist data for playlist The best driving songs (mix rock n electronic) :...   DONE
# Getting playlist data for playlist We are BUNT. :...   DONE
# Getting playlist data for playlist UK Garage / UKG :...   DONE
# Getting playlist data for playlist CAR BASS ⚡ BASS BOOSTED 🔥 CAR MUSIC REMIXES :...   DONE
# Getting playlist data for playlist Bass test: Songs for Headphones & Subwoofers :...   DONE
# Getting playlist data for playlist Jean-Michel Jarre Essential Hits :...   DONE
# Getting playlist data for playlist Ultimate HIIT Workout 2020 :...   DONE
# Getting playlist data for playlist Ibiza Mix 2019 :...   DONE
# Getting playlist data for playlist Albert Vishi Playlist :...   DONE
# Getting playlist data for playlist VERBOTEN BERLIN - Electronic Night Kitsch :...   DONE
# Getting playlist data for playlist Chill 2020 - Relaxing New Dance & Pop Music (Chill Music Playlist) :...   DONE
# Getting playlist data for playlist Festa Rave 2020 - Alok Astrix Berg Blastoyz Hi Profile Ranji Skazi Vegas Vini Vici Mandragora :...   DONE
# Getting playlist data for playlist EDM Workout & Cardio 👟 :...   DONE
# Getting playlist data for playlist Chillout 2020 :...   DONE
# Getting playlist data for playlist The Guardian: soothing songs to self-isolate with :...   DONE
# Getting playlist data for playlist Upbeat Electronica :...   DONE
# Getting playlist data for playlist LEAGUE RECAP :...   DONE
# Getting playlist data for playlist FOLK HOUSE by BUNT. :...   DONE
# Getting playlist data for playlist EDM Tiktok Songs: Tiktok Dance Songs (Electronic Tiktok Sogs 2020) Tik Tok EDM Songs 2020 :...   DONE
# Getting playlist data for playlist Deep House / Tech House :...   DONE
# Getting playlist data for playlist Female Vocal Electronica - Vocal EDM Songs :...   DONE
# Getting playlist data for playlist Christian Dance Party :...   DONE
# Getting playlist data for playlist EDM Top 40 :...   DONE
# Getting playlist data for playlist Dark Space | Ambient Electronic | IDM | Electro | EDM | Krautrock | Soundtrack | Synth :...   DONE
# Getting playlist data for playlist Instrumental Electronic Hits :...   DONE
# Getting playlist data for playlist Modern 80's Covers :...   DONE
# Getting playlist data for playlist Sad Songs for Sad Goths :...   DONE
# Getting playlist data for playlist Chill Out Songs 🌴 :...   DONE
# Getting playlist data for playlist focus beats & lofi study : electronic study music 2019 - chill electronic hip hop vibes :...   DONE
# Getting playlist data for playlist Beach Lounge 2020 & Chillout Lounge 🌴 Ibiza Sunset- Chill Electronic Pop Music - Chill Summer Music :...   DONE
# Getting playlist data for playlist EDM Club Mixes :...   DONE
# Getting playlist data for playlist Cardio Playlist :...   DONE
# Getting playlist data for playlist Top 50 EDM Songs of 2013 & 2012 :...   DONE
# Getting playlist data for playlist Club Electro - Dance - GYM Music - Summer Sounds 2020 :...   DONE

# %%
playlist_df = pd.DataFrame(playlist_lookup)
playlist_df = playlist_df.sort_values('total_followers',ascending=False)
playlist_df
# Out:
#                playlist_id                                      playlist_name  \
# 10  7ozIozDp260fjNOZy1yzRG                                      Chillout 2020
# 24  2oTrz1dYy2l970ptp4KZta                                           Chillout
# 9   4cgeOaRCHDkVDQPaDrRQFR                                Running Songs 2020
# 11  37i9dQZF1DX7SEhw42DW5b                           BPM - Today's Dance Hits
# 18  37i9dQZF1DWV3VLITCZusq                              The Climb 170-175 BPM
# ..                     ...                                                ...
# 84  3govTtbYOtkwPYg10SkDcJ  EDM Tiktok Songs: Tiktok Dance Songs (Electron...
# 8   18ScG1ZPz4XnGlzJWksQ1K                    Hot Dance/Electronic Songs 2015
# 56  41VlRPCYUtsKacWX6fTffn  Clean EDM Workout 2020 (Clean EDM Songs 2020) ...
# 1   5sTpFnFtyMwawbqsFfCwAt  Top 100 Most Popular Electronic Songs of all Time
# 6   64G4ZNRbwRxTHkWAsZvOGT                                   Electronic Songs
#
#     playlist_total_tracks                   owner_id       owner_name  \
# 10                    383               wearediamond   We Are Diamond
# 24                    168                electroposé     Electro Posé
# 9                     136  43xzlwfo0tft7hn5r5e6dksrd         LoudKult
# 11                     70                    spotify          Spotify
# 18                     51                    spotify          Spotify
# ..                    ...                        ...              ...
# 84                     55  vmopbed9tgj5wx6ctug9fig1a      Tiktok Hits
# 8                      98                 antoniox_x       antoniox_x
# 56                     54  ks5lgsyb7h25y431umnumwpcs  FITNESS ROUTINE
# 1                     114  krcghojgx24xhteqsbj990fb5            MaxiF
# 6                       5  gc2au5hff2sgwem7xfiawpwat   Walter Terrell
#
#     total_followers
# 10           678972
# 24           215903
# 9            158524
# 11            79531
# 18            74183
# ..              ...
# 84              100
# 8                68
# 56               53
# 1                33
# 6                 8
#
# [100 rows x 6 columns]

# %%
#playlist name must contain the keyword
#fix keyword matching 
KEYWORD_regex = KEYWORD.split()
playlist_df = playlist_df[playlist_df['playlist_name'].str.lower().str.contains('&'.join(KEYWORD_regex).lower())]

# %%
playlist_df.to_csv("data/"+KEYWORD+"_playlist_data.csv",encoding='utf=8',index=False)

# %% [markdown]
# ## 3. Get Tracks from a Playlist

# %% [markdown]
# ##### View the structure of a playlist_tracks query

# %%
track = sp.playlist_tracks('37i9dQZF1DX4olOMiqFeqU')

# %%
track
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4olOMiqFeqU/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7374lH6kwx9uQATYQ9H3Cp'},
#        'href': 'https://api.spotify.com/v1/artists/7374lH6kwx9uQATYQ9H3Cp',
#        'id': '7374lH6kwx9uQATYQ9H3Cp',
#        'name': 'Eraserheads',
#        'type': 'artist',
#        'uri': 'spotify:artist:7374lH6kwx9uQATYQ9H3Cp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2DIpgoeZAbwk3wF1qSDj8v'},
#      'href': 'https://api.spotify.com/v1/albums/2DIpgoeZAbwk3wF1qSDj8v',
#      'id': '2DIpgoeZAbwk3wF1qSDj8v',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27383a474e86be1eebb17df6726',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0283a474e86be1eebb17df6726',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485183a474e86be1eebb17df6726',
#        'width': 64}],
#      'name': 'Anthology',
#      'release_date': '2004-01-23',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:2DIpgoeZAbwk3wF1qSDj8v'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7374lH6kwx9uQATYQ9H3Cp'},
#       'href': 'https://api.spotify.com/v1/artists/7374lH6kwx9uQATYQ9H3Cp',
#       'id': '7374lH6kwx9uQATYQ9H3Cp',
#       'name': 'Eraserheads',
#       'type': 'artist',
#       'uri': 'spotify:artist:7374lH6kwx9uQATYQ9H3Cp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 271466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHBO10100222'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6SHSvo6OGgpneKfsxFGhhk'},
#     'href': 'https://api.spotify.com/v1/tracks/6SHSvo6OGgpneKfsxFGhhk',
#     'id': '6SHSvo6OGgpneKfsxFGhhk',
#     'is_local': False,
#     'name': 'Ligaya',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fca7a630556bff734e9f56a3efd8e0c3a1c6c2cb?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6SHSvo6OGgpneKfsxFGhhk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#        'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#        'id': '6aiCKnIN68hohzU3ZzNq48',
#        'name': 'Sarah Geronimo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/42F8uTX1DR3OiaKVtrz3Gr'},
#      'href': 'https://api.spotify.com/v1/albums/42F8uTX1DR3OiaKVtrz3Gr',
#      'id': '42F8uTX1DR3OiaKVtrz3Gr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a8ce1962ab70fd8b7d062c2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a8ce1962ab70fd8b7d062c2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a8ce1962ab70fd8b7d062c2',
#        'width': 64}],
#      'name': 'The Great Unknown',
#      'release_date': '2015-12-04',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:42F8uTX1DR3OiaKVtrz3Gr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#       'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#       'id': '6aiCKnIN68hohzU3ZzNq48',
#       'name': 'Sarah Geronimo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 245053,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHV031510085'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4T7CM071eEoHudiDShZlCJ'},
#     'href': 'https://api.spotify.com/v1/tracks/4T7CM071eEoHudiDShZlCJ',
#     'id': '4T7CM071eEoHudiDShZlCJ',
#     'is_local': False,
#     'name': 'Tala',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9e7b3a5bf3240651896e045107338ea6a3bd66f6?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4T7CM071eEoHudiDShZlCJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HIZU0JzM0AgfItVOm4E08'},
#        'href': 'https://api.spotify.com/v1/artists/5HIZU0JzM0AgfItVOm4E08',
#        'id': '5HIZU0JzM0AgfItVOm4E08',
#        'name': 'This Band',
#        'type': 'artist',
#        'uri': 'spotify:artist:5HIZU0JzM0AgfItVOm4E08'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2sGiNJNhNMJbn56l0BE0R0'},
#      'href': 'https://api.spotify.com/v1/albums/2sGiNJNhNMJbn56l0BE0R0',
#      'id': '2sGiNJNhNMJbn56l0BE0R0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273229f723cc430e9d2d8a5920a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02229f723cc430e9d2d8a5920a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851229f723cc430e9d2d8a5920a',
#        'width': 64}],
#      'name': 'Kahit Ayaw Mo Na',
#      'release_date': '2018-11-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2sGiNJNhNMJbn56l0BE0R0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HIZU0JzM0AgfItVOm4E08'},
#       'href': 'https://api.spotify.com/v1/artists/5HIZU0JzM0AgfItVOm4E08',
#       'id': '5HIZU0JzM0AgfItVOm4E08',
#       'name': 'This Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:5HIZU0JzM0AgfItVOm4E08'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243015,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCGH1864517'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/58grXgbCj7t5ulr0TGLIr9'},
#     'href': 'https://api.spotify.com/v1/tracks/58grXgbCj7t5ulr0TGLIr9',
#     'id': '58grXgbCj7t5ulr0TGLIr9',
#     'is_local': False,
#     'name': 'Kahit Ayaw Mo Na',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1dbe606aa34cd8fa75caedd742dc2310728226f7?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:58grXgbCj7t5ulr0TGLIr9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qFxP3qN9GsnZDOkAE6x2m'},
#        'href': 'https://api.spotify.com/v1/artists/4qFxP3qN9GsnZDOkAE6x2m',
#        'id': '4qFxP3qN9GsnZDOkAE6x2m',
#        'name': 'December Avenue',
#        'type': 'artist',
#        'uri': 'spotify:artist:4qFxP3qN9GsnZDOkAE6x2m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7xconhHQKj7Be4P2KvUmFz'},
#      'href': 'https://api.spotify.com/v1/albums/7xconhHQKj7Be4P2KvUmFz',
#      'id': '7xconhHQKj7Be4P2KvUmFz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273266d80116545e01826910bbd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02266d80116545e01826910bbd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851266d80116545e01826910bbd',
#        'width': 64}],
#      'name': 'Sa Ngalan Ng Pag-Ibig',
#      'release_date': '2017-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7xconhHQKj7Be4P2KvUmFz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qFxP3qN9GsnZDOkAE6x2m'},
#       'href': 'https://api.spotify.com/v1/artists/4qFxP3qN9GsnZDOkAE6x2m',
#       'id': '4qFxP3qN9GsnZDOkAE6x2m',
#       'name': 'December Avenue',
#       'type': 'artist',
#       'uri': 'spotify:artist:4qFxP3qN9GsnZDOkAE6x2m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 285138,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1753025'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00mBzIWv5gHOYxwuEJXjOG'},
#     'href': 'https://api.spotify.com/v1/tracks/00mBzIWv5gHOYxwuEJXjOG',
#     'id': '00mBzIWv5gHOYxwuEJXjOG',
#     'is_local': False,
#     'name': 'Sa Ngalan Ng Pag-Ibig',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4626adec259ce7f45bf99b287a1f263fa38e5dd1?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:00mBzIWv5gHOYxwuEJXjOG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28B54RKpJrEmDoGSTjsfY6'},
#        'href': 'https://api.spotify.com/v1/artists/28B54RKpJrEmDoGSTjsfY6',
#        'id': '28B54RKpJrEmDoGSTjsfY6',
#        'name': 'Magnus Haven',
#        'type': 'artist',
#        'uri': 'spotify:artist:28B54RKpJrEmDoGSTjsfY6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/04KG42EaTfjaPbYHQ6wI3h'},
#      'href': 'https://api.spotify.com/v1/albums/04KG42EaTfjaPbYHQ6wI3h',
#      'id': '04KG42EaTfjaPbYHQ6wI3h',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e9ea57a8a6a9607f7048b67',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e9ea57a8a6a9607f7048b67',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e9ea57a8a6a9607f7048b67',
#        'width': 64}],
#      'name': 'Imahe',
#      'release_date': '2018-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:04KG42EaTfjaPbYHQ6wI3h'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28B54RKpJrEmDoGSTjsfY6'},
#       'href': 'https://api.spotify.com/v1/artists/28B54RKpJrEmDoGSTjsfY6',
#       'id': '28B54RKpJrEmDoGSTjsfY6',
#       'name': 'Magnus Haven',
#       'type': 'artist',
#       'uri': 'spotify:artist:28B54RKpJrEmDoGSTjsfY6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 321817,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHW011800811'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/65sEZZaxTjLMD8vNgPoMz5'},
#     'href': 'https://api.spotify.com/v1/tracks/65sEZZaxTjLMD8vNgPoMz5',
#     'id': '65sEZZaxTjLMD8vNgPoMz5',
#     'is_local': False,
#     'name': 'Imahe',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3cc243dbbad2e69f14d798ecb813bf7e04efb32e?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:65sEZZaxTjLMD8vNgPoMz5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BNWanhw4AjSXjBm9L1Jzy'},
#        'href': 'https://api.spotify.com/v1/artists/4BNWanhw4AjSXjBm9L1Jzy',
#        'id': '4BNWanhw4AjSXjBm9L1Jzy',
#        'name': 'Juris',
#        'type': 'artist',
#        'uri': 'spotify:artist:4BNWanhw4AjSXjBm9L1Jzy'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7nEylzolYuExnVXy0TCPie'},
#      'href': 'https://api.spotify.com/v1/albums/7nEylzolYuExnVXy0TCPie',
#      'id': '7nEylzolYuExnVXy0TCPie',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734b1aa56e662e44b9dbd1ddcb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024b1aa56e662e44b9dbd1ddcb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514b1aa56e662e44b9dbd1ddcb',
#        'width': 64}],
#      'name': 'Forevermore',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7nEylzolYuExnVXy0TCPie'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BNWanhw4AjSXjBm9L1Jzy'},
#       'href': 'https://api.spotify.com/v1/artists/4BNWanhw4AjSXjBm9L1Jzy',
#       'id': '4BNWanhw4AjSXjBm9L1Jzy',
#       'name': 'Juris',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BNWanhw4AjSXjBm9L1Jzy'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 294716,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS091104168'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3U7TJUjNz7pgPSfgeGQjsP'},
#     'href': 'https://api.spotify.com/v1/tracks/3U7TJUjNz7pgPSfgeGQjsP',
#     'id': '3U7TJUjNz7pgPSfgeGQjsP',
#     'is_local': False,
#     'name': 'Forevermore',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43999982ee26ace4a48a993568ed062b04145746?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3U7TJUjNz7pgPSfgeGQjsP'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#        'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#        'id': '0rZRTXEmmPmx6gt92tBqIc',
#        'name': 'Moira Dela Torre',
#        'type': 'artist',
#        'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52xu8EP3ABmpNk0LUzF3ih'},
#      'href': 'https://api.spotify.com/v1/albums/52xu8EP3ABmpNk0LUzF3ih',
#      'id': '52xu8EP3ABmpNk0LUzF3ih',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6a618ab41335201afc16b81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6a618ab41335201afc16b81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6a618ab41335201afc16b81',
#        'width': 64}],
#      'name': 'Malaya (Camp Sawi Original Motion Picture Soundtrack)',
#      'release_date': '2017-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:52xu8EP3ABmpNk0LUzF3ih'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#       'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#       'id': '0rZRTXEmmPmx6gt92tBqIc',
#       'name': 'Moira Dela Torre',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 254249,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB-SMU-29-78835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6M21eWbEw74XDdoQsNIinq'},
#     'href': 'https://api.spotify.com/v1/tracks/6M21eWbEw74XDdoQsNIinq',
#     'id': '6M21eWbEw74XDdoQsNIinq',
#     'is_local': False,
#     'name': 'Malaya (Camp Sawi Original Motion Picture Soundtrack)',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/278202994437dd2ec90fbed0c08b5317eff4ad21?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6M21eWbEw74XDdoQsNIinq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nGp682WMiKS4X217kPw8C'},
#        'href': 'https://api.spotify.com/v1/artists/4nGp682WMiKS4X217kPw8C',
#        'id': '4nGp682WMiKS4X217kPw8C',
#        'name': 'Silent Sanctuary',
#        'type': 'artist',
#        'uri': 'spotify:artist:4nGp682WMiKS4X217kPw8C'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38jqi8VvSax4miNL2cacD1'},
#      'href': 'https://api.spotify.com/v1/albums/38jqi8VvSax4miNL2cacD1',
#      'id': '38jqi8VvSax4miNL2cacD1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324e40ba8327d578c9413ce36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224e40ba8327d578c9413ce36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124e40ba8327d578c9413ce36',
#        'width': 64}],
#      'name': 'Langit. Luha.',
#      'release_date': '2015-04-08',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:38jqi8VvSax4miNL2cacD1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nGp682WMiKS4X217kPw8C'},
#       'href': 'https://api.spotify.com/v1/artists/4nGp682WMiKS4X217kPw8C',
#       'id': '4nGp682WMiKS4X217kPw8C',
#       'name': 'Silent Sanctuary',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nGp682WMiKS4X217kPw8C'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 241029,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHI011405630'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0YyM8aEdbjGfLWPn6fdcn7'},
#     'href': 'https://api.spotify.com/v1/tracks/0YyM8aEdbjGfLWPn6fdcn7',
#     'id': '0YyM8aEdbjGfLWPn6fdcn7',
#     'is_local': False,
#     'name': 'Pasensya Ka Na',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/671a52310fa06ef356df56c51b6826560ce90765?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0YyM8aEdbjGfLWPn6fdcn7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Is0yeBka3hK5PSob7HTLs'},
#      'href': 'https://api.spotify.com/v1/albums/2Is0yeBka3hK5PSob7HTLs',
#      'id': '2Is0yeBka3hK5PSob7HTLs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d56bb7a4d884f0f02cac382b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d56bb7a4d884f0f02cac382b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d56bb7a4d884f0f02cac382b',
#        'width': 64}],
#      'name': 'Vince & Kath & James (Original Motion Picture Soundtrack)',
#      'release_date': '2016-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:2Is0yeBka3hK5PSob7HTLs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qnQOnL1oLKtH779qZ6iuR'},
#       'href': 'https://api.spotify.com/v1/artists/2qnQOnL1oLKtH779qZ6iuR',
#       'id': '2qnQOnL1oLKtH779qZ6iuR',
#       'name': 'Ylona Garcia',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qnQOnL1oLKtH779qZ6iuR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/69ug07KFFRhcCZ7iZ1Mn1i'},
#       'href': 'https://api.spotify.com/v1/artists/69ug07KFFRhcCZ7iZ1Mn1i',
#       'id': '69ug07KFFRhcCZ7iZ1Mn1i',
#       'name': 'Bailey May',
#       'type': 'artist',
#       'uri': 'spotify:artist:69ug07KFFRhcCZ7iZ1Mn1i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 217453,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS091605475'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6bLMHyeVCs2ki3nPUEhAjR'},
#     'href': 'https://api.spotify.com/v1/tracks/6bLMHyeVCs2ki3nPUEhAjR',
#     'id': '6bLMHyeVCs2ki3nPUEhAjR',
#     'is_local': False,
#     'name': 'O Pag-Ibig',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a832f1e678489f5aae527776481d40e5962ef39c?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6bLMHyeVCs2ki3nPUEhAjR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#        'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#        'id': '6aiCKnIN68hohzU3ZzNq48',
#        'name': 'Sarah Geronimo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BGReR0ClYIme8zAabt53h'},
#      'href': 'https://api.spotify.com/v1/albums/0BGReR0ClYIme8zAabt53h',
#      'id': '0BGReR0ClYIme8zAabt53h',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27354977fc898459edc2b4a325c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0254977fc898459edc2b4a325c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485154977fc898459edc2b4a325c',
#        'width': 64}],
#      'name': 'Maybe This Time (From "Maybe This Time")',
#      'release_date': '2016-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0BGReR0ClYIme8zAabt53h'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiCKnIN68hohzU3ZzNq48'},
#       'href': 'https://api.spotify.com/v1/artists/6aiCKnIN68hohzU3ZzNq48',
#       'id': '6aiCKnIN68hohzU3ZzNq48',
#       'name': 'Sarah Geronimo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aiCKnIN68hohzU3ZzNq48'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 255608,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS031400391'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Dljpp52vCmtXi0E94qjfo'},
#     'href': 'https://api.spotify.com/v1/tracks/0Dljpp52vCmtXi0E94qjfo',
#     'id': '0Dljpp52vCmtXi0E94qjfo',
#     'is_local': False,
#     'name': 'Maybe This Time - From "Maybe This Time"',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/34dc88427eb27b665a6f77525553cf5f612164df?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Dljpp52vCmtXi0E94qjfo'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0DnjaQqb436AH1idffI6CQ'},
#        'href': 'https://api.spotify.com/v1/artists/0DnjaQqb436AH1idffI6CQ',
#        'id': '0DnjaQqb436AH1idffI6CQ',
#        'name': 'Yeng Constantino',
#        'type': 'artist',
#        'uri': 'spotify:artist:0DnjaQqb436AH1idffI6CQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
# ...
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6LJ1p1h5EcMK4VPeCLDSoF'},
#     'href': 'https://api.spotify.com/v1/tracks/6LJ1p1h5EcMK4VPeCLDSoF',
#     'id': '6LJ1p1h5EcMK4VPeCLDSoF',
#     'is_local': False,
#     'name': 'Nadarang',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/96514a9b64fe671a0db104a98214f354e8366361?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6LJ1p1h5EcMK4VPeCLDSoF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nZa8vRD64ueq3d0JNYTsl'},
#        'href': 'https://api.spotify.com/v1/artists/3nZa8vRD64ueq3d0JNYTsl',
#        'id': '3nZa8vRD64ueq3d0JNYTsl',
#        'name': '6cyclemind',
#        'type': 'artist',
#        'uri': 'spotify:artist:3nZa8vRD64ueq3d0JNYTsl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Im5BTDBghgM0NG75SaiC3'},
#      'href': 'https://api.spotify.com/v1/albums/1Im5BTDBghgM0NG75SaiC3',
#      'id': '1Im5BTDBghgM0NG75SaiC3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273efe819c5d4a3cc6c59831852',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02efe819c5d4a3cc6c59831852',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851efe819c5d4a3cc6c59831852',
#        'width': 64}],
#      'name': 'Home',
#      'release_date': '2007-01-15',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1Im5BTDBghgM0NG75SaiC3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nZa8vRD64ueq3d0JNYTsl'},
#       'href': 'https://api.spotify.com/v1/artists/3nZa8vRD64ueq3d0JNYTsl',
#       'id': '3nZa8vRD64ueq3d0JNYTsl',
#       'name': '6cyclemind',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nZa8vRD64ueq3d0JNYTsl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 267293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHBO10700836'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2S80c51YXgJQhkhX603fMA'},
#     'href': 'https://api.spotify.com/v1/tracks/2S80c51YXgJQhkhX603fMA',
#     'id': '2S80c51YXgJQhkhX603fMA',
#     'is_local': False,
#     'name': 'Prinsesa',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/73dd68cc9e3a170dcba6457cbb470b16c7832f30?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2S80c51YXgJQhkhX603fMA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33qqYIFSFSVYO3wCkc1Ksh'},
#      'href': 'https://api.spotify.com/v1/albums/33qqYIFSFSVYO3wCkc1Ksh',
#      'id': '33qqYIFSFSVYO3wCkc1Ksh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e79447782758701854a62cef',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e79447782758701854a62cef',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e79447782758701854a62cef',
#        'width': 64}],
#      'name': 'Pauwi Nako',
#      'release_date': '2018-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:33qqYIFSFSVYO3wCkc1Ksh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iqkVK6sTXi7DZWWOeKy8Q'},
#       'href': 'https://api.spotify.com/v1/artists/0iqkVK6sTXi7DZWWOeKy8Q',
#       'id': '0iqkVK6sTXi7DZWWOeKy8Q',
#       'name': 'PDL',
#       'type': 'artist',
#       'uri': 'spotify:artist:0iqkVK6sTXi7DZWWOeKy8Q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/117XFtbZPnCI1EYKjYZWJc'},
#       'href': 'https://api.spotify.com/v1/artists/117XFtbZPnCI1EYKjYZWJc',
#       'id': '117XFtbZPnCI1EYKjYZWJc',
#       'name': 'Skusta Clee',
#       'type': 'artist',
#       'uri': 'spotify:artist:117XFtbZPnCI1EYKjYZWJc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0uD1WQbTE0pNDiJe0iGEaU'},
#       'href': 'https://api.spotify.com/v1/artists/0uD1WQbTE0pNDiJe0iGEaU',
#       'id': '0uD1WQbTE0pNDiJe0iGEaU',
#       'name': 'Jnske',
#       'type': 'artist',
#       'uri': 'spotify:artist:0uD1WQbTE0pNDiJe0iGEaU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5MfvrLwRcs98YwS3C9Uf1u'},
#       'href': 'https://api.spotify.com/v1/artists/5MfvrLwRcs98YwS3C9Uf1u',
#       'id': '5MfvrLwRcs98YwS3C9Uf1u',
#       'name': 'Bullet D',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MfvrLwRcs98YwS3C9Uf1u'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xOvrnVpLjzfGi69GDlzQY'},
#       'href': 'https://api.spotify.com/v1/artists/5xOvrnVpLjzfGi69GDlzQY',
#       'id': '5xOvrnVpLjzfGi69GDlzQY',
#       'name': 'Yuridope',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xOvrnVpLjzfGi69GDlzQY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3PDFGpPl4ienSn5Vwisfrh'},
#       'href': 'https://api.spotify.com/v1/artists/3PDFGpPl4ienSn5Vwisfrh',
#       'id': '3PDFGpPl4ienSn5Vwisfrh',
#       'name': 'Flow G',
#       'type': 'artist',
#       'uri': 'spotify:artist:3PDFGpPl4ienSn5Vwisfrh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 341573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADT1835182'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2tzAN1L07SNwnOdgOEeuQr'},
#     'href': 'https://api.spotify.com/v1/tracks/2tzAN1L07SNwnOdgOEeuQr',
#     'id': '2tzAN1L07SNwnOdgOEeuQr',
#     'is_local': False,
#     'name': 'Pauwi Nako',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/26122cea968dfa29f6270901cbab215158b01a2b?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2tzAN1L07SNwnOdgOEeuQr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-05T08:50:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#        'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#        'id': '0rZRTXEmmPmx6gt92tBqIc',
#        'name': 'Moira Dela Torre',
#        'type': 'artist',
#        'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/05rQadwAVYTpNNnBoeTuj0'},
#      'href': 'https://api.spotify.com/v1/albums/05rQadwAVYTpNNnBoeTuj0',
#      'id': '05rQadwAVYTpNNnBoeTuj0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27384c39a72230ca78d8223dcec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0284c39a72230ca78d8223dcec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485184c39a72230ca78d8223dcec',
#        'width': 64}],
#      'name': 'Malaya',
#      'release_date': '2018-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:05rQadwAVYTpNNnBoeTuj0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rZRTXEmmPmx6gt92tBqIc'},
#       'href': 'https://api.spotify.com/v1/artists/0rZRTXEmmPmx6gt92tBqIc',
#       'id': '0rZRTXEmmPmx6gt92tBqIc',
#       'name': 'Moira Dela Torre',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rZRTXEmmPmx6gt92tBqIc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 320320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PHS031700772'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/70bc7AZ8MN5niphOXyHpsD'},
#     'href': 'https://api.spotify.com/v1/tracks/70bc7AZ8MN5niphOXyHpsD',
#     'id': '70bc7AZ8MN5niphOXyHpsD',
#     'is_local': False,
#     'name': 'Malaya',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fe7a31b266d4b9f2487b4e38cf133db05ef0480e?cid=66e3ee219f2a4fd7a1ea4af766807d7a',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:70bc7AZ8MN5niphOXyHpsD'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 50}

# %%
track.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
track['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %% [markdown]
# ***

# %%
#get only top 20 followed playlists
playlist_df = playlist_df.head(20)

# %%
def get_relevant_track_data(tracks_data, playlist_id, playlist_name):
    try:
        relevant_track_data = { key: tracks_data['track'][key] for key in ['id','artists','name','popularity','duration_ms'] }
        relevant_track_data['artist_id']=[artist['id'] for artist in relevant_track_data['artists'] ]
        relevant_track_data['artist_name']=[artist['name']for artist in relevant_track_data['artists'] ]
        relevant_track_data['num_artists']=len([artist['id'] for artist in relevant_track_data['artists']]) 
        relevant_track_data['playlist_id']=playlist_id
        relevant_track_data['playlist_name']=playlist_name
        
        relevant_track_data.pop('artists', None)
        return relevant_track_data
    except:
        return

# %%
#playlist_tracks
all_track_data = []

for _,p_id,p_name, p_numtracks in playlist_df[['playlist_id','playlist_name','playlist_total_tracks']].to_records():
    print("Fetching data for playlist = %s, with total tracks: %d" % (p_name,p_numtracks))
    n_fetches = p_numtracks // 100
    
    playlist_track_data = []
    #get tracks in batches of 100
    for n in np.arange(n_fetches+1):
        track_data = sp.playlist_tracks(p_id, offset=n*100)
        playlist_track_data.extend([get_relevant_track_data(item, p_id,p_name) for item in track_data['items']])
        
    all_track_data.extend(playlist_track_data)

# %%
for n,a in enumerate(all_track_data):
    try:
        len(a)
    except:
        print(n)

# %%
tracks_df = pd.DataFrame([data for data in all_track_data if data is not None])
tracks_df = tracks_df.rename(columns={'id':'track_id'})
tracks_df['artist_id'] = tracks_df.apply(lambda x: x['artist_id'][0] if x['num_artists']==1 else x['artist_id'], axis=1)
tracks_df['artist_name'] = tracks_df.apply(lambda x: x['artist_name'][0] if x['num_artists']==1 else x['artist_name'], axis=1)
tracks_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'artist_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1070         try:
# -> 1071             loc = self.items.get_loc(item)
#    1072         except KeyError:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'artist_id'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-22a9546a9e4b> in <module>
#       1 tracks_df = pd.DataFrame([data for data in all_track_data if data is not None])
#       2 tracks_df = tracks_df.rename(columns={'id':'track_id'})
# ----> 3 tracks_df['artist_id'] = tracks_df.apply(lambda x: x['artist_id'][0] if x['num_artists']==1 else x['artist_id'], axis=0)
#       4 tracks_df['artist_name'] = tracks_df.apply(lambda x: x['artist_name'][0] if x['num_artists']==1 else x['artist_name'], axis=0)
#       5 tracks_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1072         except KeyError:
#    1073             # This item wasn't present, just insert at end
# -> 1074             self.insert(len(self.items), item, value)
#    1075             return
#    1076
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1179         new_axis = self.items.insert(loc, item)
#    1180
# -> 1181         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1182
#    1183         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3051         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3052
# -> 3053     return klass(values, ndim=ndim, placement=placement)
#    3054
#    3055
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     122
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 124             raise ValueError(
#     125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 0, placement implies 1

# %%
len(tracks_df)

# %%
len(tracks_df['track_id'].unique())

# %%
tracks_df.to_csv("data/"+KEYWORD+"_playlist_tracks.csv",encoding='utf=8',index=False)

# %% [markdown]
# ## 4. Get Tracks Data from a list of Tracks

# %%
tracks_df = pd.read_csv("data/"+KEYWORD+"_playlist_tracks.csv")
tracks_df.head()

# %%
tracks_df.shape

# %%
#remove track duplicates
tracks_df = tracks_df.drop_duplicates(subset='track_id')
tracks_df.shape

# %%
def get_track_data(t_id, playlist_id,playlist_name):                    
    track_data = sp.track(t_id)
    track_features = sp.audio_features(t_id)
    
    #get only main(first) artist
    td_list = [t_id,\
               track_data['name'],\
               track_data['artists'][0]['id'],\
               track_data['artists'][0]['name'],\
               track_data['album']['uri'].split(":")[2],\
               track_data['duration_ms'],\
               track_data['album']['release_date'],\
               track_data['popularity']]
    data = pd.DataFrame([td_list], columns = ['track_id','track_name','artist_id','artist_name','album_id','duration','release_date','popularity'])

    relevant_cols = ['danceability', 'energy', 'key', 'loudness', 'mode',\
                     'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']  
    
    tf_data = pd.DataFrame(track_features)
    tf_data = tf_data[relevant_cols]
    #tag with source playlist
    tf_data['playlist_id'] = playlist_id
    tf_data['playlist_name'] = playlist_name
    
    data = pd.concat([data, tf_data], axis=1)
    return data

# %%
downloaded_track_data = []

# %%
track_list = tracks_df['track_id'].values
playlist_name_list = tracks_df['playlist_name'].values
playlist_id_list = tracks_df['playlist_id'].values
df_list=[]

for i,track_id in enumerate(track_list):
    try:
        if track_id not in downloaded_track_data:
            print('[%d/%d] Fetching track data for %s... ' % 
                  (i+1,len(track_list),tracks_df[tracks_df['track_id']==track_id]['name'].values[0]), end = " ") 
            track_data = get_track_data(track_id, playlist_id_list[i],playlist_name_list[i]) 
            df_list.append(track_data)
            downloaded_track_data.append(track_id)
            print('done!')
    except:
        continue
    else:
        continue
    
    #sleep for 60 secs per 100 requests to avoid being blocked
    if (i % 100 == 0)&(i > 0):
        time.sleep(5)

# %%
tracks_data_df = pd.concat(df_list)
tracks_data_df.head()

# %%
tracks_data_df.to_csv("data/"+KEYWORD+"_playlist_tracks_data.csv", index=False, encoding='utf-8')
